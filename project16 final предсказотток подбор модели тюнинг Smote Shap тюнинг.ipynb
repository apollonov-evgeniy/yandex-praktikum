# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Привет, Евгений!</b>
#
# Меня зовут Ярослав П. Поздравляю с финишной прямой! Уверен, что путь был нелегкий, но надеюсь, что интересный.
#
# Предлагаю общаться на «**ты**». Если это неприемлемо, обязательно напиши мне в комментариях — мы перейдем на «**вы**».
#
# Ниже ты найдешь мои комментарии - пожалуйста, не перемещай, не изменяй и не удаляй их. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger">
# <b>Комментарий ревьюера:</b> Так выделены самые важные замечания. Без их отработки проект не будет принят. </div>
#
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b> Так выделены небольшие замечания или советы.
#
# </div>
#
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b> Так я выделяю все остальные комментарии.</div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комменатри — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.
#
#
# ### <span style="color:orange">Обратная связь</span><a class="tocSkip">
#
# - Ты основательно подошел к выполнению проекта. Видно, что вложено много сил и они дали свой результат.
# - Шаг по анализу и подготовке данных выполнен отлично.
# - Протестировано много моделей - это верный подход. Финальный результат тоже отличный.
# - Теперь к недочетам. Единственный важный связан с настройкой scaler. Оставил комментарий.
# - Также было бы здорово добавить чуть больше комментариев, в частности, про анализ.
#
# ### <span style="color:orange">Обратная связь (v2)</span><a class="tocSkip">
#
# - Проект отлично доработан, спасибо за уделенное время!
#
# Проект принят, поздравляю!

# %% [markdown]
# <b>Предсказание оттока клиентов оператора связи
# Условие задачи</b>
#
# Оператор связи «Ниединогоразрыва.ком» хочет научиться прогнозировать отток клиентов. Если выяснится, что пользователь планирует уйти, ему будут предложены промокоды и специальные условия. Команда оператора собрала персональные данные о некоторых клиентах, информацию об их тарифах и договорах.
#
# Описание услуг
#
# Оператор предоставляет два основных типа услуг:
#
# * Стационарную телефонную связь.
# Возможно подключение телефонного аппарата к нескольким линиям одновременно.
#
# * Интернет.
# Подключение может быть двух типов: через телефонную линию (DSL, от англ. digital subscriber line, «цифровая абонентская линия») или оптоволоконный кабель (Fiber optic).
# Также доступны такие услуги:  Интернет-безопасность: антивирус (DeviceProtection) и блокировка небезопасных сайтов (OnlineSecurity); Выделенная линия технической поддержки (TechSupport);  Облачное хранилище файлов для резервного копирования данных (OnlineBackup);  Стриминговое телевидение (StreamingTV) и каталог фильмов (StreamingMovies).
#
#
# За услуги клиенты могут платить каждый месяц или заключить договор на 1–2 года. Доступны различные способы расчёта и возможность получения электронного чека.
#
# * Описание данных
#
# Данные состоят из файлов, полученных из разных источников:
#
# contract.csv — информация о договоре;
# personal.csv — персональные данные клиента;
# internet.csv — информация об интернет-услугах;
# phone.csv — информация об услугах телефонии.
# Во всех файлах столбец customerID содержит код клиента.
#
# Информация о договорах актуальна на 1 февраля 2020.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#План" data-toc-modified-id="План-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>План</a></span></li><li><span><a href="#Подготовка-и-анализ-данных." data-toc-modified-id="Подготовка-и-анализ-данных.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка и анализ данных.</a></span></li><li><span><a href="#Обработка-данных" data-toc-modified-id="Обработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Обработка данных</a></span></li><li><span><a href="#Столбец-целевого-признака,-обработка-дат" data-toc-modified-id="Столбец-целевого-признака,-обработка-дат-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Столбец целевого признака, обработка дат</a></span></li><li><span><a href="#Дополнительные-фичи" data-toc-modified-id="Дополнительные-фичи-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Дополнительные фичи</a></span></li><li><span><a href="#Объединение-данных,-кодирование" data-toc-modified-id="Объединение-данных,-кодирование-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Объединение данных, кодирование</a></span></li><li><span><a href="#Обучение-модели-с-дефолтными-значениями" data-toc-modified-id="Обучение-модели-с-дефолтными-значениями-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Обучение модели с дефолтными значениями</a></span></li><li><span><a href="#График-важности-фичей" data-toc-modified-id="График-важности-фичей-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>График важности фичей</a></span></li><li><span><a href="#Тюнинг" data-toc-modified-id="Тюнинг-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Тюнинг</a></span></li><li><span><a href="#RandomForestClassifier-and-LogisticRegression" data-toc-modified-id="RandomForestClassifier-and-LogisticRegression-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>RandomForestClassifier and LogisticRegression</a></span></li><li><span><a href="#GradientBoostingClassifier" data-toc-modified-id="GradientBoostingClassifier-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>GradientBoostingClassifier</a></span></li><li><span><a href="#LGBMClassifier" data-toc-modified-id="LGBMClassifier-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>LGBMClassifier</a></span></li><li><span><a href="#Catboost" data-toc-modified-id="Catboost-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Catboost</a></span></li><li><span><a href="#Лучшие-модели" data-toc-modified-id="Лучшие-модели-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Лучшие модели</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>Вывод:</a></span></li><li><span><a href="#Отчет-по-решению" data-toc-modified-id="Отчет-по-решению-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>Отчет по решению</a></span></li></ul></div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера</b>
#
# Отличное введение.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий ревьюера</b>
#
# Также было бы здорово добавить название проекта, оглавление и воспользоваться разметкой markdown (оформить списки, что-то выделить курсивом и т.д.).
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера (v2)</b>
#
# Отлично!
#
# </div>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import glob
import os

# %matplotlib inline
import matplotlib.pyplot as plt

import random
random_state=123
random.seed(random_state)
np.random.seed(random_state)

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %%
#!pip install lightgbm

# %%
#!pip install shap
#conda install -c conda-forge shap

# %%
from catboost import CatBoostClassifier, Pool 

from sklearn.utils import shuffle

from sklearn.dummy import DummyClassifier

from sklearn.preprocessing import MinMaxScaler, StandardScaler

from sklearn.tree import DecisionTreeClassifier

from sklearn.naive_bayes import GaussianNB

from sklearn.svm import SVC

from sklearn.neural_network import MLPClassifier

from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier,ExtraTreesClassifier, RandomForestClassifier

from lightgbm import LGBMClassifier

from sklearn.linear_model import LogisticRegression

from sklearn.model_selection import train_test_split, GridSearchCV

from sklearn.metrics import accuracy_score, roc_auc_score, classification_report, roc_curve

from sklearn import metrics

#import shap не установился в тренажере

from sklearn.pipeline import Pipeline

import lightgbm as lgb

# %% [markdown]
# # План
# 1. Чтение файлов с данными и изучение общей информаций
# 2. Создание дополнительных признаков (target_churn, phone, internet,срок контракта в месяцах, предлагаются дополнительные признаки: разделить клиентов на короткие и длинные договора, низкий или высокий ежемесячный платеж)
# 3. Слияние в единый датафрейм
# 4. Исключение признаков с датами и TotalCharges.
# 5. Кодирование категориальных признаков и нормализация численных. Разделение на train и valid
# 6. Обучение модели RandomForest, Выбор важных признаков, удаление ненужных признаков
# 7. Обучение нескольких моделей (от простых к сложным) на сформированной выборке. выбор перспективных. Тюнинг модели
# 8. Выводы и рекомендации

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера</b>
#
# Хорошо, план есть, идем дальше.
#
# </div>

# %% [markdown]
# # Подготовка и анализ данных.

# %%
#phone = pd.read_csv('phone.csv', index_col = 'customerID')
#contract = pd.read_csv('contract.csv', index_col = 'customerID')
#personal = pd.read_csv('personal.csv', index_col = 'customerID')
#internet = pd.read_csv('internet.csv', index_col = 'customerID')

contract = pd.read_csv('/datasets/final_provider/contract.csv', index_col = 'customerID')
phone = pd.read_csv('/datasets/final_provider/phone.csv', index_col = 'customerID')
personal = pd.read_csv('/datasets/final_provider/personal.csv', index_col = 'customerID')
internet = pd.read_csv('/datasets/final_provider/internet.csv', index_col = 'customerID')

# %%
def df_describe (df):
    display(df.info())
    display(df.sample(20))
    display(df.describe(exclude=[np.number]))
    display(df.describe())

# %%
df_describe(contract)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 7 columns):
# BeginDate           7043 non-null object
# EndDate             7043 non-null object
# Type                7043 non-null object
# PaperlessBilling    7043 non-null object
# PaymentMethod       7043 non-null object
# MonthlyCharges      7043 non-null float64
# TotalCharges        7043 non-null object
# dtypes: float64(1), object(6)
# memory usage: 440.2+ KB
# None
#              BeginDate              EndDate            Type PaperlessBilling  \
# customerID
# 0811-GSDTP  2019-01-01                   No  Month-to-month               No
# 1970-KKFWL  2017-03-01                   No        Two year               No
# 2892-GESUL  2018-08-01                   No        Two year               No
# 2842-BCQGE  2016-07-01                   No  Month-to-month              Yes
# 4807-IZYOZ  2015-11-01                   No        Two year               No
# 9451-WLYRI  2015-09-01                   No        One year               No
# 1767-TGTKO  2019-06-01                   No  Month-to-month              Yes
# 8033-VCZGH  2015-12-01                   No        One year              Yes
# 6689-VRRTK  2016-06-01                   No        One year              Yes
# 6997-UVGOX  2014-03-01                   No        Two year               No
# 1602-IJQQE  2019-09-01  2020-01-01 00:00:00  Month-to-month               No
# 6976-BWGLQ  2014-02-01                   No        Two year               No
# 8066-POXGX  2018-11-01  2019-12-01 00:00:00  Month-to-month              Yes
# 5862-BRIXZ  2016-04-01                   No        Two year              Yes
# 5317-FLPJF  2014-08-01                   No        Two year              Yes
# 4193-IBKSW  2014-02-01                   No        Two year               No
# 8680-CGLTP  2017-09-01                   No        One year              Yes
# 0616-ATFGB  2019-09-01  2019-10-01 00:00:00  Month-to-month               No
# 0426-TIRNE  2019-11-01  2019-12-01 00:00:00  Month-to-month               No
# 5549-ZGHFB  2015-12-01                   No        Two year               No
#
#                         PaymentMethod  MonthlyCharges TotalCharges
# customerID
# 0811-GSDTP           Electronic check           30.15        382.2
# 1970-KKFWL  Bank transfer (automatic)           23.30        797.1
# 2892-GESUL               Mailed check           19.35       309.25
# 2842-BCQGE    Credit card (automatic)           75.35       3161.4
# 4807-IZYOZ  Bank transfer (automatic)           20.65      1020.75
# 9451-WLYRI    Credit card (automatic)           19.05       990.45
# 1767-TGTKO           Electronic check           45.45       411.75
# 8033-VCZGH           Electronic check          103.95       5231.3
# 6689-VRRTK    Credit card (automatic)          109.80      4860.35
# 6997-UVGOX  Bank transfer (automatic)           85.45       6029.9
# 1602-IJQQE           Electronic check           75.35        338.1
# 6976-BWGLQ  Bank transfer (automatic)           25.20      1787.35
# 8066-POXGX           Electronic check           35.10        446.1
# 5862-BRIXZ  Bank transfer (automatic)           60.75       2893.4
# 5317-FLPJF  Bank transfer (automatic)           61.35       4193.4
# 4193-IBKSW  Bank transfer (automatic)           24.75       1769.6
# 8680-CGLTP           Electronic check           58.75       1696.2
# 0616-ATFGB           Electronic check           25.05        25.05
# 0426-TIRNE               Mailed check           20.90         20.9
# 5549-ZGHFB               Mailed check           24.95      1261.45
#          BeginDate EndDate            Type PaperlessBilling     PaymentMethod  \
# count         7043    7043            7043             7043              7043
# unique          77       5               3                2                 4
# top     2014-02-01      No  Month-to-month              Yes  Electronic check
# freq           366    5174            3875             4171              2365
#
#        TotalCharges
# count          7043
# unique         6531
# top
# freq             11
#        MonthlyCharges
# count     7043.000000
# mean        64.761692
# std         30.090047
# min         18.250000
# 25%         35.500000
# 50%         70.350000
# 75%         89.850000
# max        118.750000

# %%
df_describe(personal)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 4 columns):
# gender           7043 non-null object
# SeniorCitizen    7043 non-null int64
# Partner          7043 non-null object
# Dependents       7043 non-null object
# dtypes: int64(1), object(3)
# memory usage: 275.1+ KB
# None
#             gender  SeniorCitizen Partner Dependents
# customerID
# 2167-FQSTQ  Female              0     Yes         No
# 6794-HKIAJ    Male              0      No         No
# 5918-VUKWP  Female              0      No         No
# 5898-IGSLP    Male              0     Yes        Yes
# 4952-YSOGZ  Female              0     Yes        Yes
# 4801-JZAZL  Female              0     Yes        Yes
# 0258-NOKBL    Male              0      No         No
# 8645-KWHJO    Male              0      No         No
# 6908-VVYHM    Male              0     Yes         No
# 2157-MXBJS    Male              0     Yes         No
# 1877-HKBQX  Female              0      No         No
# 2208-NKVVH    Male              0     Yes        Yes
# 4821-SJHJV  Female              0     Yes        Yes
# 5575-TPIZQ    Male              0      No         No
# 4353-HYOJD  Female              0     Yes        Yes
# 6987-XQSJT  Female              1      No         No
# 1415-YFWLT  Female              1      No         No
# 5751-USDBL    Male              0     Yes        Yes
# 7246-ZGQDF  Female              0      No        Yes
# 4971-PUYQO  Female              0      No         No
#        gender Partner Dependents
# count    7043    7043       7043
# unique      2       2          2
# top      Male      No         No
# freq     3555    3641       4933
#        SeniorCitizen
# count    7043.000000
# mean        0.162147
# std         0.368612
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
df_describe(phone)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6361 entries, 5575-GNVDE to 3186-AJIEK
# Data columns (total 1 columns):
# MultipleLines    6361 non-null object
# dtypes: object(1)
# memory usage: 99.4+ KB
# None
#            MultipleLines
# customerID
# 0730-KOAVE           Yes
# 7601-WFVZV            No
# 2550-QHZGP            No
# 1194-SPVSP            No
# 3363-EWLGO            No
# 1891-FZYSA           Yes
# 9921-QFQUL           Yes
# 9412-ARGBX            No
# 7346-MEDWM           Yes
# 5995-OIGLP            No
# 3354-OADJP            No
# 4559-UWIHT           Yes
# 9470-XCCEM           Yes
# 6372-RFVNS            No
# 6710-HSJRD           Yes
# 3315-TOTBP           Yes
# 8851-RAGOV            No
# 6131-FOYAS           Yes
# 8654-DHAOW           Yes
# 4957-TIALW            No
#        MultipleLines
# count           6361
# unique             2
# top               No
# freq            3390
#        MultipleLines
# count           6361
# unique             2
# top               No
# freq            3390

# %%
df_describe(internet)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5517 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 7 columns):
# InternetService     5517 non-null object
# OnlineSecurity      5517 non-null object
# OnlineBackup        5517 non-null object
# DeviceProtection    5517 non-null object
# TechSupport         5517 non-null object
# StreamingTV         5517 non-null object
# StreamingMovies     5517 non-null object
# dtypes: object(7)
# memory usage: 344.8+ KB
# None
#            InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# customerID
# 5077-DXTCG             DSL             No           No               No
# 4291-TPNFG             DSL            Yes          Yes              Yes
# 7492-TAFJD             DSL            Yes          Yes              Yes
# 7521-AFHAB             DSL             No           No               No
# 2709-UQGNP             DSL            Yes           No               No
# 4070-OKWVH     Fiber optic             No          Yes              Yes
# 1907-UBQFC     Fiber optic             No          Yes               No
# 2985-JUUBZ             DSL             No           No              Yes
# 2754-SDJRD     Fiber optic             No           No               No
# 2880-FPNAE     Fiber optic             No           No              Yes
# 0823-HSCDJ             DSL             No          Yes               No
# 0928-XUTSN     Fiber optic             No           No               No
# 0018-NYROU     Fiber optic             No           No               No
# 2862-PFNIK             DSL             No           No               No
# 3128-YOVTD     Fiber optic            Yes          Yes               No
# 0679-IDSTG     Fiber optic             No           No               No
# 0988-JRWWP             DSL             No           No               No
# 2794-XIMMO             DSL             No          Yes              Yes
# 1818-ESQMW     Fiber optic             No           No              Yes
# 2984-AFWNC     Fiber optic             No          Yes               No
#
#            TechSupport StreamingTV StreamingMovies
# customerID
# 5077-DXTCG          No          No              No
# 4291-TPNFG         Yes          No             Yes
# 7492-TAFJD          No          No              No
# 7521-AFHAB          No          No              No
# 2709-UQGNP          No          No              No
# 4070-OKWVH          No         Yes              No
# 1907-UBQFC          No          No              No
# 2985-JUUBZ          No         Yes             Yes
# 2754-SDJRD         Yes         Yes             Yes
# 2880-FPNAE          No          No              No
# 0823-HSCDJ          No         Yes             Yes
# 0928-XUTSN          No          No             Yes
# 0018-NYROU          No          No              No
# 2862-PFNIK          No          No              No
# 3128-YOVTD          No          No              No
# 0679-IDSTG          No          No              No
# 0988-JRWWP          No         Yes              No
# 2794-XIMMO         Yes         Yes             Yes
# 1818-ESQMW         Yes          No             Yes
# 2984-AFWNC          No         Yes             Yes
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             5517           5517         5517             5517
# unique               2              2            2                2
# top        Fiber optic             No           No               No
# freq              3096           3498         3088             3095
#
#        TechSupport StreamingTV StreamingMovies
# count         5517        5517            5517
# unique           2           2               2
# top             No          No              No
# freq          3473        2810            2785
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             5517           5517         5517             5517
# unique               2              2            2                2
# top        Fiber optic             No           No               No
# freq              3096           3498         3088             3095
#
#        TechSupport StreamingTV StreamingMovies
# count         5517        5517            5517
# unique           2           2               2
# top             No          No              No
# freq          3473        2810            2785

# %% [markdown]
# # Обработка данных

# %%
contract.TotalCharges=pd.to_numeric(contract.TotalCharges, errors='coerce') # перевод в float
contract.TotalCharges.fillna(0, inplace=True) # замена на 0, тк новые контракты

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера</b>
#
# Молодец, что заметил и обработал эти значения. С решением согласен.
#
# </div>

# %%
personal.SeniorCitizen=personal.SeniorCitizen.astype('object')

# %%
contract.BeginDate = pd.to_datetime(contract.BeginDate,format='%Y%m%d ') # в datatime

# %% [markdown]
# # Столбец целевого признака, обработка дат

# %%
target = "target"
contract['target'] = (contract.EndDate != 'No').astype(int) # столбец целевой признак

# %%
sns.countplot(contract['target'] )

# %%
contract['target'] .value_counts(normalize=True).plot(kind="pie")

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера</b>
#
# Здорово, что оценил баланс классов.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий ревьюера</b>
#
# Мне еще нравится выводить баланс классов в процентах.
#
# </div>

# %%
contract.EndDate =  contract.EndDate.replace('No', str('2020-02-01 00:00:00'))
contract.EndDate = pd.to_datetime(contract.EndDate,format='%Y%m%d ') # в datatime
 # актуальная дата

# %%
# Месяцы и дни контракта
contract['days_contract']=(contract.EndDate-contract.BeginDate).dt.days
contract['months_contract']=round((contract.EndDate-contract.BeginDate).dt.days/30).astype('int')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера</b>
#
# Хорошие признаки. Но сильно скоррелированные. Нужны ли нам оба?
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Изначально разделил на месяцы, но без дней не получалась точность. Если смотреть график важности фичей, ои дополняют друг друга. Есть некоторая зависимость помесечная</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера (v2)</b>
#
# Хорошо, принято.
#
# </div>

# %%
plt.figure(num=None, figsize=(12, 4), dpi=80, facecolor='w', edgecolor='k')

x1 = contract[contract.target==1].MonthlyCharges
x2 = contract[contract.target==0].MonthlyCharges
plt.subplot(1, 2, 1)
plt.hist(x1, color = 'b', alpha=0.6, bins =100)
plt.xlabel('MonthlyCharges')
plt.title('Ушедшие Клиенты ')
plt.grid()

plt.subplot(1, 2, 2)
plt.hist(x2, color = 'r', label = '', alpha=0.6, bins=100)
plt.xlabel('MonthlyCharges')
plt.title('Действуюшие клиенты')
plt.grid()

plt.show()

# %%
plt.figure(num=None, figsize=(12, 4), dpi=80, facecolor='w', edgecolor='k')

x1 = contract[contract.target==1].months_contract
x2 = contract[contract.target==0].months_contract
plt.subplot(1, 2, 1)
plt.hist(x1, color = 'b', alpha=0.6, bins =100)
plt.xlabel('Месяцы контракта')
plt.title('Ушедшие Клиенты ')
plt.grid()

plt.subplot(1, 2, 2)
plt.hist(x2, color = 'r', label = '', alpha=0.6, bins=100)
plt.xlabel('Месяцы контракта')
plt.title('Действуюшие клиенты')
plt.grid()

plt.show()

# %%
contract.MonthlyCharges.describe()
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: MonthlyCharges, dtype: float64

# %%
contract.months_contract.describe()
# Out:
# count    7043.000000
# mean       32.831180
# std        25.004181
# min         0.000000
# 25%         9.000000
# 50%        29.000000
# 75%        56.000000
# max        73.000000
# Name: months_contract, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера</b>
#
# Хороший анализ данных.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий ревьюера</b>
#
# Однако практически нет комментариев/выводов. Было бы здорово их добавить.
#
# </div>

# %% [markdown]
# # Дополнительные фичи

# %%
contract['long_contract']=1
contract.loc[(contract.months_contract <35),'long_contract'] = 0 # Короткий или длинный контракт

contract['pricy_contract']=1
contract.loc[(contract.MonthlyCharges <60),'pricy_contract'] = 0 #большой или маленький ежемесячный платеж



contract['pay_auto_contract']=1
contract.loc[(contract.PaymentMethod =='Electronic check') | (contract.PaymentMethod =='Mailed check') ,
             'pay_auto_contract'] = 0 # платеж с признаком авто

contract['type_year_contract']=1
contract.loc[(contract.Type =='Month-to-month'),
             'type_year_contract'] = 0 # ежемесячный или годовой платеж

phone['phone']="Yes" # наличие телефона

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера</b>
#
# Интересные фичи.
#
# </div>

# %% [markdown]
# # Объединение данных, кодирование

# %%
data = pd.merge(contract, personal, left_index=True, right_index=True)
data  = data.join(internet)
data = data.join(phone)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 27 columns):
# BeginDate             7043 non-null datetime64[ns]
# EndDate               7043 non-null datetime64[ns]
# Type                  7043 non-null object
# PaperlessBilling      7043 non-null object
# PaymentMethod         7043 non-null object
# MonthlyCharges        7043 non-null float64
# TotalCharges          7043 non-null float64
# target                7043 non-null int64
# days_contract         7043 non-null int64
# months_contract       7043 non-null int64
# long_contract         7043 non-null int64
# pricy_contract        7043 non-null int64
# pay_auto_contract     7043 non-null int64
# type_year_contract    7043 non-null int64
# gender                7043 non-null object
# SeniorCitizen         7043 non-null object
# Partner               7043 non-null object
# Dependents            7043 non-null object
# InternetService       5517 non-null object
# OnlineSecurity        5517 non-null object
# OnlineBackup          5517 non-null object
# DeviceProtection      5517 non-null object
# TechSupport           5517 non-null object
# StreamingTV           5517 non-null object
# StreamingMovies       5517 non-null object
# MultipleLines         6361 non-null object
# phone                 6361 non-null object
# dtypes: datetime64[ns](2), float64(2), int64(7), object(16)
# memory usage: 1.8+ MB

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера</b>
#
# Объединения корректны.
#
# </div>

# %%
#заполняем пропуски после объединения
 
for k in [['InternetService','OnlineSecurity', 'OnlineBackup', 'DeviceProtection','TechSupport',
           'StreamingTV','StreamingMovies']]:
    data[k] = data[k].fillna('No') # 

data['MultipleLines']=data['MultipleLines'].fillna('NA')
data['phone']=data['phone'].fillna('No')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера</b>
#
# Пропуски заполнены, отлично.
#
# </div>

# %% [markdown]
# DATA

# %%
data.head()
# Out:
#             BeginDate    EndDate            Type PaperlessBilling  \
# customerID
# 7590-VHVEG 2020-01-01 2020-02-01  Month-to-month              Yes
# 5575-GNVDE 2017-04-01 2020-02-01        One year               No
# 3668-QPYBK 2019-10-01 2019-12-01  Month-to-month              Yes
# 7795-CFOCW 2016-05-01 2020-02-01        One year               No
# 9237-HQITU 2019-09-01 2019-11-01  Month-to-month              Yes
#
#                         PaymentMethod  MonthlyCharges  TotalCharges  target  \
# customerID
# 7590-VHVEG           Electronic check           29.85         29.85       0
# 5575-GNVDE               Mailed check           56.95       1889.50       0
# 3668-QPYBK               Mailed check           53.85        108.15       1
# 7795-CFOCW  Bank transfer (automatic)           42.30       1840.75       0
# 9237-HQITU           Electronic check           70.70        151.65       1
#
#             days_contract  months_contract  long_contract  pricy_contract  \
# customerID
# 7590-VHVEG             31                1              0               0
# 5575-GNVDE           1036               35              1               0
# 3668-QPYBK             61                2              0               0
# 7795-CFOCW           1371               46              1               0
# 9237-HQITU             61                2              0               1
#
#             pay_auto_contract  type_year_contract  gender SeniorCitizen  \
# customerID
# 7590-VHVEG                  0                   0  Female             0
# 5575-GNVDE                  0                   1    Male             0
# 3668-QPYBK                  0                   0    Male             0
# 7795-CFOCW                  1                   1    Male             0
# 9237-HQITU                  0                   0  Female             0
#
#            Partner Dependents InternetService OnlineSecurity OnlineBackup  \
# customerID
# 7590-VHVEG     Yes         No             DSL             No          Yes
# 5575-GNVDE      No         No             DSL            Yes           No
# 3668-QPYBK      No         No             DSL            Yes          Yes
# 7795-CFOCW      No         No             DSL            Yes           No
# 9237-HQITU      No         No     Fiber optic             No           No
#
#            DeviceProtection TechSupport StreamingTV StreamingMovies  \
# customerID
# 7590-VHVEG               No          No          No              No
# 5575-GNVDE              Yes          No          No              No
# 3668-QPYBK               No          No          No              No
# 7795-CFOCW              Yes         Yes          No              No
# 9237-HQITU               No          No          No              No
#
#            MultipleLines phone
# customerID
# 7590-VHVEG            NA    No
# 5575-GNVDE            No   Yes
# 3668-QPYBK            No   Yes
# 7795-CFOCW            NA    No
# 9237-HQITU            No   Yes

# %%
# производим кодирование и нормализацию
# двоичные значения
# сначала кодирование

#for col in data.select_dtypes("object").columns:
#         data[col] = pd.Categorical(data[col]).codes
        
for col in data.select_dtypes("object").columns:
    if sorted(data[col].unique())==["No","Yes"]:
          data[col] = (data[col] == "Yes").astype("uint8")
            
data["gender"] = (data["gender"] == "Male").astype("uint8")



data.SeniorCitizen=data.SeniorCitizen.astype('uint8')
data.long_contract=data.long_contract.astype('uint8')
data.pricy_contract=data.pricy_contract.astype('uint8')
data.pay_auto_contract=data.pay_auto_contract.astype('uint8')
data.type_year_contract=data.type_year_contract.astype('uint8')  
        
data = pd.get_dummies(data, drop_first=True)

# удаляем поля даты
data = data.drop(['BeginDate', 'EndDate'] , axis=1)

data=data.reset_index(drop=True)

features = list(set(data.columns) - set([target]))

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий ревьюера</b>
#
# Насколько я знаю, для get_dummies необязательно переводить признаки в численный формат.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Такое кодирование делал для себя, чтоб лучше видеть структуру</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера (v2)</b>
#
# Хорошо.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера</b>
#
# Правильно, что используешь drop_first=True.
#
# Также молодец, что удалил признаки с датами, они бы создавали утечку таргета.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий ревьюера</b>
#
# Выбор способов кодирования категориальных признаков обычно основывается на выбранной модели. Для линейной (логистической) регрессии - OHE, для деревьев - Ordinal, бустингам подходит Ordinal или встроенное в них кодирование. Линрегу не подходит Ordinal, так как он пытается все рассчитать по формулам, и мы можем столкнуться с проблемой, что женщины (с порядковым номером 1) будут "важнее" мужчин (с порядковым номером 0) (или Москва "важнее" "Казани"), к примеру. Для деревьев же не подходит OHE, так как дерево получается неправильной формы, перекошенные, увеличивается время обучения (так как признаков больше), в целом снижается эффективность модели. По [ссылке](https://towardsdatascience.com/one-hot-encoding-is-making-your-tree-based-ensembles-worse-heres-why-d64b282b5769) есть более подробная информация по этому поводу. Также там есть изображения "правильных" и "перекошенных" деревьев.
#
# Хоть на такой подход, как я описал выше, и можно ориентироваться, лучший друг в нашем деле - это эксперимент. Так что стоит экспериментировать с разными способами кодирования.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Смотрел разные варианты, остановился на этом, как наиболее оптимальном для разных моделей. Столбцов OHE не так много.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера (v2)</b>
#
# Да, в данном случае это некритично.
#
# </div>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 30 columns):
# PaperlessBilling                         7043 non-null uint8
# MonthlyCharges                           7043 non-null float64
# TotalCharges                             7043 non-null float64
# target                                   7043 non-null int64
# days_contract                            7043 non-null int64
# months_contract                          7043 non-null int64
# long_contract                            7043 non-null uint8
# pricy_contract                           7043 non-null uint8
# pay_auto_contract                        7043 non-null uint8
# type_year_contract                       7043 non-null uint8
# gender                                   7043 non-null uint8
# SeniorCitizen                            7043 non-null uint8
# Partner                                  7043 non-null uint8
# Dependents                               7043 non-null uint8
# OnlineSecurity                           7043 non-null uint8
# OnlineBackup                             7043 non-null uint8
# DeviceProtection                         7043 non-null uint8
# TechSupport                              7043 non-null uint8
# StreamingTV                              7043 non-null uint8
# StreamingMovies                          7043 non-null uint8
# phone                                    7043 non-null uint8
# Type_One year                            7043 non-null uint8
# Type_Two year                            7043 non-null uint8
# PaymentMethod_Credit card (automatic)    7043 non-null uint8
# PaymentMethod_Electronic check           7043 non-null uint8
# PaymentMethod_Mailed check               7043 non-null uint8
# InternetService_Fiber optic              7043 non-null uint8
# InternetService_No                       7043 non-null uint8
# MultipleLines_No                         7043 non-null uint8
# MultipleLines_Yes                        7043 non-null uint8
# dtypes: float64(2), int64(3), uint8(25)
# memory usage: 822.1+ KB

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий ревьюера</b>
#
# <s>Обрати внимание, что scaler нужно обучать только на тренировочной выборке. Иначе это может привести к переобучению. Это имитация работы с настоящими данными. Когда у нас есть обучающая выборка, мы на ней учим scaler, на ней обучаем модель. То есть наша модель и scaler не могут знать тех данных, которые в нее будут загружаться при ее использовании.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Исправил ниже.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера (v2)</b>
#
# Отлично, вижу.
#
# </div>

# %%
#разбивка
train, test = train_test_split(data, test_size=0.3, random_state=12)
valid, test = train_test_split(test, test_size=0.5, random_state=12)

# %%
X_train, y_train = train[features], train[target]
X_valid, y_valid = valid[features], valid[target]
X_test, y_test = test[features], test[target]

# %%
# затем нормирование
scaler = MinMaxScaler()
#scaler = StandardScaler()
numeric_cols = ["days_contract","TotalCharges","MonthlyCharges", "months_contract"]

X_train[numeric_cols] = scaler.fit_transform(X_train[numeric_cols]) # fit it on the training data
X_valid[numeric_cols] = scaler.transform(X_valid[numeric_cols])
X_test[numeric_cols] = scaler.transform(X_test[numeric_cols])

# %%
# oversampling  не улучшает качество модели.
# !pip install -U imbalanced-learn
# 
#    from imblearn.over_sampling import SMOTE
#    smote = SMOTE()#sampling_strategy='minority')
#    X_sm, y_sm = smote.fit_resample(X_train, y_train)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера</b>
#
# Здорово, что поэкспериментировал.
#
# </div>

# %% [markdown]
# # Обучение модели с дефолтными значениями

# %%
classifiers = [['DecisionTree :',DecisionTreeClassifier()],
               ['RandomForest :',RandomForestClassifier()],
               ['Naive Bayes :', GaussianNB()],
               ['LGBMClassifier :', LGBMClassifier()],
               ['SVM :', SVC(probability=True)],
               ['Neural Network :', MLPClassifier()],
               ['LogisticRegression :', LogisticRegression()],
               ['ExtraTreesClassifier :', ExtraTreesClassifier()],
               ['AdaBoostClassifier :', AdaBoostClassifier()],
               ['GradientBoostingClassifier: ', GradientBoostingClassifier()],
               ['CatBoost :', CatBoostClassifier(logging_level='Silent')]
              ]


for name,classifier in classifiers:
    classifier = classifier
    classifier.fit(X_train, y_train)
    predictions = classifier.predict(X_valid)
    print(name)
    print('valid_accuracy: ', accuracy_score(y_valid, predictions))
    print('valid_Roc_auc score: ', roc_auc_score(y_valid, classifier.predict_proba(X_valid)[:,1]),'\n')
# Out:
# DecisionTree :
# valid_accuracy:  0.7840909090909091
# valid_Roc_auc score:  0.7080137051489483
#
# RandomForest :
# valid_accuracy:  0.8011363636363636
# valid_Roc_auc score:  0.8196821166841153
#
# Naive Bayes :
# valid_accuracy:  0.75
# valid_Roc_auc score:  0.8399210050442562
#
# LGBMClassifier :
# valid_accuracy:  0.853219696969697
# valid_Roc_auc score:  0.8872537356048349
#
# SVM :
# valid_accuracy:  0.8087121212121212
# valid_Roc_auc score:  0.8311197297040069
#
# Neural Network :
# valid_accuracy:  0.7982954545454546
# valid_Roc_auc score:  0.8270295993147424
#
# LogisticRegression :
# valid_accuracy:  0.8115530303030303
# valid_Roc_auc score:  0.8498001332445037
#
# ExtraTreesClassifier :
# valid_accuracy:  0.78125
# valid_Roc_auc score:  0.78197392214714
#
# AdaBoostClassifier :
# valid_accuracy:  0.8295454545454546
# valid_Roc_auc score:  0.8674930998382031
#
# GradientBoostingClassifier:
# valid_accuracy:  0.8503787878787878
# valid_Roc_auc score:  0.8870324545541068
#
# CatBoost :
# valid_accuracy:  0.865530303030303
# valid_Roc_auc score:  0.9006900161796896

# %% [markdown]
# Для дальнейшего тюнинга возьмем RandomForest,  LGBMClassifier, GradientBoostingClassifier,  CatBoost
# на основе RandomForest построим график важности фичей

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера</b>
#
# Бустинги даже так дают отличные результаты, что же даст тюнинг? :)
#
# </div>

# %% [markdown]
# # График важности фичей

# %%
rf = RandomForestClassifier(random_state=12, class_weight='balanced')
rf.fit(X_train, y_train)

y_pred_test = rf.predict(X_valid)

samples = X_train

explainer = shap.TreeExplainer(rf)
shap_values = explainer.shap_values(samples, approximate=False, check_additivity=False)

shap.summary_plot(shap_values[1], samples)

# %% [markdown]
# график важности фичей
# Как его читать:
#
# значения слева от центральной вертикальной линии — это negative класс (0), справа — positive (1)
# чем толще линия на графике, тем больше таких точек наблюдения
# чем краснее точки на графике, тем выше значения фичи в ней
#
# Можно сразу сформировать портрет уходящего клиента:
# недавно заключивший контракт, подключенный к интернету по оптической линии, с высокой помесячной оплатой,получающий электронный чек, тип олаты electronic check и не автоматический, пользующийся стриминговами сервисами

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера</b>
#
# С первого взгляда непонятный график, но, если разобраться, очень полезный. Здорово, что ты его освоил.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> График дает очень много информации по внутренней работе алгоритма. Очень долго считает. В тренажере shap не установился. Не перезапускал</div>

# %% [markdown]
# # Тюнинг

# %% [markdown]
# # RandomForestClassifier and LogisticRegression

# %%
# Create first pipeline for base without reducing features.

pipe = Pipeline([('classifier' , RandomForestClassifier())])

param_grid = [
    {'classifier' : [LogisticRegression()],
     'classifier__penalty' : ['l1', 'l2'],
    'classifier__C' : np.logspace(-4, 4, 20),
    'classifier__solver' : ['liblinear']},
    {'classifier' : [RandomForestClassifier()],
    'classifier__n_estimators' : list(range(10,501,10)),
    'classifier__max_features' : ['auto', 'sqrt', 'log2'],
    'classifier__criterion' : ['gini', 'entropy']}
]


clf = GridSearchCV(pipe, param_grid = param_grid, scoring=['f1', 'accuracy', 'roc_auc'], 
                   refit='roc_auc', cv = 5, verbose=True, n_jobs=-1)

best_clf = clf.fit(X_train, y_train)

probs = best_clf.predict_proba(X_valid)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_valid, preds)
roc_auc = metrics.auc(fpr, tpr)

print('valid_Roc_auc score: ', roc_auc)
plt.figure()
plt.plot(fpr, tpr, label='GridSearchCV (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
# Out:
# Fitting 5 folds for each of 340 candidates, totalling 1700 fits
# [Parallel(n_jobs=-1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 1700 out of 1700 | elapsed: 47.5min finished
# valid_Roc_auc score:  0.8553416769772534

# %%
# Results from Grid Search
print("\n========================================================")
print(" Results from Grid Search " )
print("========================================================")    
print("\n The best estimator across ALL searched params:\n",
          best_clf.best_estimator_)    
print("\n The best score across ALL searched params:\n",
          best_clf.best_score_)
print("\n The best parameters across ALL searched params:\n",
          best_clf.best_params_)
print("\n ========================================================")
# Out:
# ========================================================
#  Results from Grid Search
# ========================================================
#
#  The best estimator across ALL searched params:
#  Pipeline(memory=None,
#          steps=[('classifier',
#                  RandomForestClassifier(bootstrap=True, class_weight=None,
#                                         criterion='gini', max_depth=None,
#                                         max_features='auto',
#                                         max_leaf_nodes=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         n_estimators=450, n_jobs=None,
#                                         oob_score=False, random_state=None,
#                                         verbose=0, warm_start=False))],
#          verbose=False)
#
#  The best score across ALL searched params:
#  0.8502437220518654
#
#  The best parameters across ALL searched params:
#  {'classifier': RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=450,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False), 'classifier__criterion': 'gini', 'classifier__max_features': 'auto', 'classifier__n_estimators': 450}
#
#  ========================================================

# %%
#используем найденные гиперпараметры для обучения и проверки на тестовой выборке
model_rfc= RandomForestClassifier(criterion = 'gini', max_features = 'auto', 
                                  n_estimators = 450, random_state=12)
model_rfc.fit(X_train, y_train)

probabilities_valid = model_rfc.predict_proba(X_test)
probabilities_one_valid = probabilities_valid[:, 1]
fpr_rfc, tpr_rfc, threshold_rfc = metrics.roc_curve(y_test, probabilities_one_valid)
roc_auc = metrics.auc(fpr_rfc, tpr_rfc)          
print('test_Roc_auc score: ',roc_auc)
pred_rfc=model_rfc.predict(X_test)
print(classification_report(y_test, pred_rfc))
# Out:
# test_Roc_auc score:  0.8502622705133009
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88       785
#            1       0.69      0.58      0.63       272
#
#     accuracy                           0.82      1057
#    macro avg       0.77      0.74      0.76      1057
# weighted avg       0.82      0.82      0.82      1057

# %% [markdown]
# # GradientBoostingClassifier

# %%
model = GradientBoostingClassifier()
param_grid = {'learning_rate': [0.01, 0.03],
                  'subsample'    : [1,  0.2],
                  'n_estimators' : [100, 1750],
                  'max_depth'    : [4,6] 
                 }
grid = GridSearchCV(estimator=model, param_grid = param_grid, cv = 5, n_jobs=-1)
grid.fit(X_train, y_train)

probs = grid.predict_proba(X_valid)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_valid, preds)
roc_auc = metrics.auc(fpr, tpr)

print('valid_Roc_auc score: ', roc_auc)
plt.figure()
plt.plot(fpr, tpr, label='GridSearchCV (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
# Out:
# valid_Roc_auc score:  0.9235224136290092

# %%
    # Results from Grid Search
print("\n========================================================")
print(" Results from Grid Search " )
print("========================================================")    
    
print("\n The best estimator across ALL searched params:\n",
          grid.best_estimator_)
print("\n The best score across ALL searched params:\n",
          grid.best_score_)
print("\n The best parameters across ALL searched params:\n",
          grid.best_params_)
print("\n ========================================================")
# Out:
# ========================================================
#  Results from Grid Search
# ========================================================
#
#  The best estimator across ALL searched params:
#  GradientBoostingClassifier(criterion='friedman_mse', init=None,
#                            learning_rate=0.03, loss='deviance', max_depth=4,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=1750,
#                            n_iter_no_change=None, presort='auto',
#                            random_state=None, subsample=1, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)
#
#  The best score across ALL searched params:
#  0.8578093306288033
#
#  The best parameters across ALL searched params:
#  {'learning_rate': 0.03, 'max_depth': 4, 'n_estimators': 1750, 'subsample': 1}
#
#  ========================================================

# %%
#используем найденные гиперпараметры для обучения и проверки на тестовой выборке
model_gbl = GradientBoostingClassifier(learning_rate=0.03, n_estimators=1750,max_depth=4,  
                                     subsample=1, random_state=12)
model_gbl.fit(X_train,y_train)


probabilities_valid = model_gbl.predict_proba(X_test)
probabilities_one_valid = probabilities_valid[:, 1]

fpr_gbl, tpr_gbl, threshold_gbl = metrics.roc_curve(y_test, probabilities_one_valid)
roc_auc = metrics.auc(fpr_gbl, tpr_gbl)    

print('test_Roc_auc score: ',roc_auc)

pred_gbl=model_gbl.predict(X_test)
print(classification_report(y_test, pred_gbl))
# Out:
# test_Roc_auc score:  0.9146730985387785
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91       785
#            1       0.75      0.72      0.73       272
#
#     accuracy                           0.87      1057
#    macro avg       0.83      0.82      0.82      1057
# weighted avg       0.86      0.87      0.86      1057

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий ревьюера</b>
#
# Также можно попробовать обучить модель на выборке трейн+валид с подобранными гиперпараметрами и потом прогнать на тесте.
#
# Логика такая. В нашем случае у нас не было отдельного датасета для тестирования, мы отрезали от основного небольшую часть (отложенная выборка). То есть остальные данные мы используем для обучения. Если обучить только на обучающей, что у нас полностью теряются валидационные данные - мы их не используем в модели, но они то у нас есть, жаль их выбрасывать.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> В конце сделал на лучшей модели.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера (v2)</b>
#
# 👍
#
# </div>

# %% [markdown]
# # LGBMClassifier

# %%
baseline_lgmc = LGBMClassifier()
baseline_lgmc.fit(X_train, y_train)

# To view the default model params:
baseline_lgmc.get_params()
# Out:
# {'boosting_type': 'gbdt',
#  'class_weight': None,
#  'colsample_bytree': 1.0,
#  'importance_type': 'split',
#  'learning_rate': 0.1,
#  'max_depth': -1,
#  'min_child_samples': 20,
#  'min_child_weight': 0.001,
#  'min_split_gain': 0.0,
#  'n_estimators': 100,
#  'n_jobs': -1,
#  'num_leaves': 31,
#  'objective': None,
#  'random_state': None,
#  'reg_alpha': 0.0,
#  'reg_lambda': 0.0,
#  'silent': True,
#  'subsample': 1.0,
#  'subsample_for_bin': 200000,
#  'subsample_freq': 0}

# %%
params = {'boosting_type': 'gbdt',
          'max_depth' : -1,
          'num_leaves': 31,
          'learning_rate': 0.1,
          'max_bin': 512,
          'subsample_for_bin': 200000,
          'subsample': 1.0,
          'subsample_freq': 0,
          'colsample_bytree': 1.0,
          'reg_alpha': 0.0,
          'reg_lambda': 0.0,
          'min_split_gain': 0.0,
          'min_child_weight': 0.001,
          'min_child_samples': 20,
          'scale_pos_weight': 1,
             }


gridParams = {
    'learning_rate': [0.1, 0.5],
    'n_estimators': [50, 100],
    'num_leaves': [6,12,16,32,64],
    'random_state' : [12],
    'colsample_bytree' : [0.5,0.65,1.0],
    'subsample' : [0.5, 0.7,1.0],
    'reg_alpha' : [0.0, 1],
    'reg_lambda' : [0.0, 1],
    }


best_lgmc = lgb.LGBMClassifier(boosting_type= 'gbdt',
          objective = 'binary',
          n_jobs = -1, 
          silent = True,
          max_depth = params['max_depth'],
          max_bin = params['max_bin'],
          subsample_for_bin = params['subsample_for_bin'],
          subsample = params['subsample'],
          subsample_freq = params['subsample_freq'],
          min_split_gain = params['min_split_gain'],
          min_child_weight = params['min_child_weight'],
          min_child_samples = params['min_child_samples'],
          scale_pos_weight = params['scale_pos_weight'])


grid = GridSearchCV(best_lgmc, gridParams,
                    verbose=0,
                    cv=4,
                    n_jobs=-1)

grid.fit(X_train, y_train)

probs = grid.predict_proba(X_valid)
preds = probs[:,1]

fpr, tpr, threshold = metrics.roc_curve(y_valid, preds)
roc_auc = metrics.auc(fpr, tpr)

print('valid_Roc_auc score: ', roc_auc)
plt.figure()
plt.plot(fpr, tpr, label='GridSearchCV (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
# Out:
# valid_Roc_auc score:  0.9077876653659465

# %%
# Results from Grid Search
print("\n========================================================")
print(" Results from Grid Search " )
print("========================================================")    
    
print("\n The best estimator across ALL searched params:\n",
          grid.best_estimator_)
print("\n The best score across ALL searched params:\n",
          grid.best_score_)
print("\n The best parameters across ALL searched params:\n",
          grid.best_params_)
print("\n ========================================================")
# Out:
# ========================================================
#  Results from Grid Search
# ========================================================
#
#  The best estimator across ALL searched params:
#  LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=0.5,
#                importance_type='split', learning_rate=0.5, max_bin=512,
#                max_depth=-1, min_child_samples=20, min_child_weight=0.001,
#                min_split_gain=0.0, n_estimators=100, n_jobs=-1, num_leaves=12,
#                objective='binary', random_state=12, reg_alpha=1, reg_lambda=0.0,
#                scale_pos_weight=1, silent=True, subsample=0.5,
#                subsample_for_bin=200000, subsample_freq=0)
#
#  The best score across ALL searched params:
#  0.8452332657200812
#
#  The best parameters across ALL searched params:
#  {'colsample_bytree': 0.5, 'learning_rate': 0.5, 'n_estimators': 100, 'num_leaves': 12, 'random_state': 12, 'reg_alpha': 1, 'reg_lambda': 0.0, 'subsample': 0.5}
#
#  ========================================================

# %%
#используем найденные гиперпараметры для обучения
model_lgb = lgb.LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=0.5,
               importance_type='split', learning_rate=0.5, max_bin=512,
               max_depth=-1, min_child_samples=20, min_child_weight=0.001,
               min_split_gain=0.0, n_estimators=100, n_jobs=-1, num_leaves=12,
               objective='binary', random_state=12, reg_alpha=1, reg_lambda=0.0,
               scale_pos_weight=1, silent=True, subsample=0.5,
               subsample_for_bin=200000, subsample_freq=0)
model_lgb.fit(X_train, y_train)

probabilities_valid = model_lgb.predict_proba(X_test)
probabilities_one_valid = probabilities_valid[:, 1]

fpr_lgb, tpr_lgb, threshold_lgb = metrics.roc_curve(y_test, probabilities_one_valid)
roc_auc = metrics.auc(fpr_lgb, tpr_lgb)    

print('test_Roc_auc score: ',roc_auc)

pred_lgb=model_lgb.predict(X_test)
print(classification_report(y_test, pred_lgb))
# Out:
# test_Roc_auc score:  0.8924878231547395
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.90       785
#            1       0.73      0.67      0.70       272
#
#     accuracy                           0.85      1057
#    macro avg       0.81      0.79      0.80      1057
# weighted avg       0.85      0.85      0.85      1057

# %% [markdown]
# # Catboost

# %%
model_cb_1 = CatBoostClassifier(eval_metric='AUC')

param_grid = {'learning_rate': [0.03, 0.1], 'depth': [4, 6], 'l2_leaf_reg': [1, 3]}

grid = GridSearchCV(estimator=model_cb_1, param_grid = param_grid, cv = 5, n_jobs=-1)
grid.fit(X_train, y_train)

probs = grid.predict_proba(X_valid)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_valid, preds)
roc_auc = metrics.auc(fpr, tpr)

print('valid_Roc_auc score: ', roc_auc)
plt.figure()
plt.plot(fpr, tpr, label='GridSearchCV (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

#grid_search_result = model_cb_1.grid_search(param_grid, X=X_train, y=y_train, cv=5, plot=True)
# Out:
# 0:	total: 9.16ms	remaining: 9.15s
# 1:	total: 11.9ms	remaining: 5.95s
# 2:	total: 14.4ms	remaining: 4.78s
# 3:	total: 19.6ms	remaining: 4.88s
# 4:	total: 98.5ms	remaining: 19.6s
# 5:	total: 101ms	remaining: 16.8s
# 6:	total: 106ms	remaining: 15.1s
# 7:	total: 111ms	remaining: 13.7s
# 8:	total: 115ms	remaining: 12.7s
# 9:	total: 196ms	remaining: 19.4s
# 10:	total: 199ms	remaining: 17.9s
# 11:	total: 202ms	remaining: 16.6s
# 12:	total: 205ms	remaining: 15.5s
# 13:	total: 209ms	remaining: 14.7s
# 14:	total: 292ms	remaining: 19.2s
# 15:	total: 295ms	remaining: 18.2s
# 16:	total: 298ms	remaining: 17.2s
# 17:	total: 300ms	remaining: 16.4s
# 18:	total: 303ms	remaining: 15.6s
# 19:	total: 311ms	remaining: 15.2s
# 20:	total: 390ms	remaining: 18.2s
# 21:	total: 394ms	remaining: 17.5s
# 22:	total: 396ms	remaining: 16.8s
# 23:	total: 399ms	remaining: 16.2s
# 24:	total: 401ms	remaining: 15.7s
# 25:	total: 410ms	remaining: 15.4s
# 26:	total: 487ms	remaining: 17.5s
# 27:	total: 490ms	remaining: 17s
# 28:	total: 492ms	remaining: 16.5s
# 29:	total: 495ms	remaining: 16s
# 30:	total: 497ms	remaining: 15.5s
# 31:	total: 500ms	remaining: 15.1s
# 32:	total: 584ms	remaining: 17.1s
# 33:	total: 587ms	remaining: 16.7s
# 34:	total: 590ms	remaining: 16.3s
# 35:	total: 592ms	remaining: 15.9s
# 36:	total: 595ms	remaining: 15.5s
# 37:	total: 607ms	remaining: 15.4s
# 38:	total: 681ms	remaining: 16.8s
# 39:	total: 684ms	remaining: 16.4s
# 40:	total: 687ms	remaining: 16.1s
# 41:	total: 689ms	remaining: 15.7s
# 42:	total: 692ms	remaining: 15.4s
# 43:	total: 700ms	remaining: 15.2s
# 44:	total: 778ms	remaining: 16.5s
# 45:	total: 781ms	remaining: 16.2s
# 46:	total: 783ms	remaining: 15.9s
# 47:	total: 786ms	remaining: 15.6s
# 48:	total: 789ms	remaining: 15.3s
# 49:	total: 793ms	remaining: 15.1s
# 50:	total: 874ms	remaining: 16.3s
# 51:	total: 877ms	remaining: 16s
# 52:	total: 879ms	remaining: 15.7s
# 53:	total: 882ms	remaining: 15.5s
# 54:	total: 885ms	remaining: 15.2s
# 55:	total: 893ms	remaining: 15s
# 56:	total: 971ms	remaining: 16.1s
# 57:	total: 974ms	remaining: 15.8s
# 58:	total: 977ms	remaining: 15.6s
# 59:	total: 979ms	remaining: 15.3s
# 60:	total: 982ms	remaining: 15.1s
# 61:	total: 984ms	remaining: 14.9s
# 62:	total: 1.07s	remaining: 15.9s
# 63:	total: 1.07s	remaining: 15.7s
# 64:	total: 1.07s	remaining: 15.5s
# 65:	total: 1.08s	remaining: 15.3s
# 66:	total: 1.09s	remaining: 15.1s
# 67:	total: 1.17s	remaining: 16s
# 68:	total: 1.17s	remaining: 15.8s
# 69:	total: 1.17s	remaining: 15.5s
# 70:	total: 1.17s	remaining: 15.3s
# 71:	total: 1.18s	remaining: 15.2s
# 72:	total: 1.18s	remaining: 15s
# 73:	total: 1.19s	remaining: 14.8s
# 74:	total: 1.26s	remaining: 15.6s
# 75:	total: 1.26s	remaining: 15.4s
# 76:	total: 1.27s	remaining: 15.2s
# 77:	total: 1.27s	remaining: 15s
# 78:	total: 1.28s	remaining: 14.9s
# 79:	total: 1.36s	remaining: 15.6s
# 80:	total: 1.36s	remaining: 15.4s
# 81:	total: 1.36s	remaining: 15.3s
# 82:	total: 1.37s	remaining: 15.1s
# 83:	total: 1.37s	remaining: 14.9s
# 84:	total: 1.38s	remaining: 14.8s
# 85:	total: 1.46s	remaining: 15.5s
# 86:	total: 1.46s	remaining: 15.3s
# 87:	total: 1.46s	remaining: 15.2s
# 88:	total: 1.47s	remaining: 15s
# 89:	total: 1.47s	remaining: 14.9s
# 90:	total: 1.55s	remaining: 15.5s
# 91:	total: 1.55s	remaining: 15.3s
# 92:	total: 1.56s	remaining: 15.2s
# 93:	total: 1.56s	remaining: 15s
# 94:	total: 1.56s	remaining: 14.9s
# 95:	total: 1.57s	remaining: 14.8s
# 96:	total: 1.65s	remaining: 15.3s
# 97:	total: 1.65s	remaining: 15.2s
# 98:	total: 1.65s	remaining: 15.1s
# 99:	total: 1.66s	remaining: 14.9s
# 100:	total: 1.66s	remaining: 14.8s
# 101:	total: 1.67s	remaining: 14.7s
# 102:	total: 1.68s	remaining: 14.6s
# 103:	total: 1.68s	remaining: 14.5s
# 104:	total: 1.68s	remaining: 14.3s
# 105:	total: 1.69s	remaining: 14.2s
# 106:	total: 1.69s	remaining: 14.1s
# 107:	total: 1.69s	remaining: 14s
# 108:	total: 1.7s	remaining: 13.9s
# 109:	total: 1.78s	remaining: 14.4s
# 110:	total: 1.78s	remaining: 14.3s
# 111:	total: 1.78s	remaining: 14.1s
# 112:	total: 1.78s	remaining: 14s
# 113:	total: 1.79s	remaining: 13.9s
# 114:	total: 1.79s	remaining: 13.8s
# 115:	total: 1.87s	remaining: 14.3s
# 116:	total: 1.88s	remaining: 14.2s
# 117:	total: 1.88s	remaining: 14s
# 118:	total: 1.88s	remaining: 13.9s
# 119:	total: 1.88s	remaining: 13.8s
# 120:	total: 1.89s	remaining: 13.7s
# 121:	total: 1.97s	remaining: 14.2s
# 122:	total: 1.97s	remaining: 14.1s
# 123:	total: 1.97s	remaining: 13.9s
# 124:	total: 1.98s	remaining: 13.8s
# 125:	total: 1.98s	remaining: 13.7s
# 126:	total: 1.99s	remaining: 13.7s
# 127:	total: 2.07s	remaining: 14.1s
# 128:	total: 2.07s	remaining: 14s
# 129:	total: 2.07s	remaining: 13.9s
# 130:	total: 2.08s	remaining: 13.8s
# 131:	total: 2.08s	remaining: 13.7s
# 132:	total: 2.09s	remaining: 13.6s
# 133:	total: 2.16s	remaining: 14s
# 134:	total: 2.17s	remaining: 13.9s
# 135:	total: 2.17s	remaining: 13.8s
# 136:	total: 2.17s	remaining: 13.7s
# 137:	total: 2.17s	remaining: 13.6s
# 138:	total: 2.18s	remaining: 13.5s
# 139:	total: 2.18s	remaining: 13.4s
# 140:	total: 2.26s	remaining: 13.8s
# 141:	total: 2.26s	remaining: 13.7s
# 142:	total: 2.27s	remaining: 13.6s
# 143:	total: 2.27s	remaining: 13.5s
# 144:	total: 2.28s	remaining: 13.4s
# 145:	total: 2.36s	remaining: 13.8s
# 146:	total: 2.36s	remaining: 13.7s
# 147:	total: 2.36s	remaining: 13.6s
# 148:	total: 2.36s	remaining: 13.5s
# 149:	total: 2.37s	remaining: 13.4s
# 150:	total: 2.37s	remaining: 13.3s
# 151:	total: 2.38s	remaining: 13.3s
# 152:	total: 2.45s	remaining: 13.6s
# 153:	total: 2.46s	remaining: 13.5s
# 154:	total: 2.46s	remaining: 13.4s
# 155:	total: 2.46s	remaining: 13.3s
# 156:	total: 2.46s	remaining: 13.2s
# 157:	total: 2.47s	remaining: 13.2s
# 158:	total: 2.55s	remaining: 13.5s
# 159:	total: 2.55s	remaining: 13.4s
# 160:	total: 2.55s	remaining: 13.3s
# 161:	total: 2.56s	remaining: 13.2s
# 162:	total: 2.56s	remaining: 13.1s
# 163:	total: 2.57s	remaining: 13.1s
# 164:	total: 2.65s	remaining: 13.4s
# 165:	total: 2.65s	remaining: 13.3s
# 166:	total: 2.65s	remaining: 13.2s
# 167:	total: 2.65s	remaining: 13.1s
# 168:	total: 2.66s	remaining: 13.1s
# 169:	total: 2.67s	remaining: 13s
# 170:	total: 2.75s	remaining: 13.3s
# 171:	total: 2.75s	remaining: 13.2s
# 172:	total: 2.75s	remaining: 13.2s
# 173:	total: 2.75s	remaining: 13.1s
# 174:	total: 2.76s	remaining: 13s
# 175:	total: 2.77s	remaining: 12.9s
# 176:	total: 2.84s	remaining: 13.2s
# 177:	total: 2.84s	remaining: 13.1s
# 178:	total: 2.85s	remaining: 13.1s
# 179:	total: 2.85s	remaining: 13s
# 180:	total: 2.85s	remaining: 12.9s
# 181:	total: 2.86s	remaining: 12.8s
# 182:	total: 2.94s	remaining: 13.1s
# 183:	total: 2.94s	remaining: 13s
# 184:	total: 2.94s	remaining: 13s
# 185:	total: 2.95s	remaining: 12.9s
# 186:	total: 2.96s	remaining: 12.8s
# 187:	total: 3.03s	remaining: 13.1s
# 188:	total: 3.04s	remaining: 13s
# 189:	total: 3.04s	remaining: 13s
# 190:	total: 3.04s	remaining: 12.9s
# 191:	total: 3.13s	remaining: 13.2s
# 192:	total: 3.13s	remaining: 13.1s
# 193:	total: 3.14s	remaining: 13s
# 194:	total: 3.14s	remaining: 13s
# 195:	total: 3.14s	remaining: 12.9s
# 196:	total: 3.15s	remaining: 12.8s
# 197:	total: 3.23s	remaining: 13.1s
# 198:	total: 3.23s	remaining: 13s
# 199:	total: 3.23s	remaining: 12.9s
# 200:	total: 3.23s	remaining: 12.9s
# 201:	total: 3.24s	remaining: 12.8s
# 202:	total: 3.24s	remaining: 12.7s
# 203:	total: 3.25s	remaining: 12.7s
# 204:	total: 3.33s	remaining: 12.9s
# 205:	total: 3.33s	remaining: 12.8s
# 206:	total: 3.33s	remaining: 12.8s
# 207:	total: 3.33s	remaining: 12.7s
# 208:	total: 3.34s	remaining: 12.6s
# 209:	total: 3.34s	remaining: 12.6s
# 210:	total: 3.42s	remaining: 12.8s
# 211:	total: 3.42s	remaining: 12.7s
# 212:	total: 3.43s	remaining: 12.7s
# 213:	total: 3.43s	remaining: 12.6s
# 214:	total: 3.43s	remaining: 12.5s
# 215:	total: 3.43s	remaining: 12.5s
# 216:	total: 3.44s	remaining: 12.4s
# 217:	total: 3.52s	remaining: 12.6s
# 218:	total: 3.52s	remaining: 12.6s
# 219:	total: 3.52s	remaining: 12.5s
# 220:	total: 3.53s	remaining: 12.4s
# 221:	total: 3.53s	remaining: 12.4s
# 222:	total: 3.54s	remaining: 12.3s
# 223:	total: 3.62s	remaining: 12.5s
# 224:	total: 3.62s	remaining: 12.5s
# 225:	total: 3.62s	remaining: 12.4s
# 226:	total: 3.62s	remaining: 12.3s
# 227:	total: 3.63s	remaining: 12.3s
# 228:	total: 3.63s	remaining: 12.2s
# 229:	total: 3.65s	remaining: 12.2s
# 230:	total: 3.71s	remaining: 12.4s
# 231:	total: 3.72s	remaining: 12.3s
# 232:	total: 3.72s	remaining: 12.2s
# 233:	total: 3.72s	remaining: 12.2s
# 234:	total: 3.72s	remaining: 12.1s
# 235:	total: 3.73s	remaining: 12.1s
# 236:	total: 3.81s	remaining: 12.3s
# 237:	total: 3.81s	remaining: 12.2s
# 238:	total: 3.81s	remaining: 12.1s
# 239:	total: 3.82s	remaining: 12.1s
# 240:	total: 3.82s	remaining: 12s
# 241:	total: 3.83s	remaining: 12s
# 242:	total: 3.91s	remaining: 12.2s
# 243:	total: 3.91s	remaining: 12.1s
# 244:	total: 3.91s	remaining: 12.1s
# 245:	total: 3.92s	remaining: 12s
# 246:	total: 3.92s	remaining: 11.9s
# 247:	total: 3.92s	remaining: 11.9s
# 248:	total: 4s	remaining: 12.1s
# 249:	total: 4.01s	remaining: 12s
# 250:	total: 4.01s	remaining: 12s
# 251:	total: 4.01s	remaining: 11.9s
# 252:	total: 4.02s	remaining: 11.9s
# 253:	total: 4.03s	remaining: 11.8s
# 254:	total: 4.1s	remaining: 12s
# 255:	total: 4.1s	remaining: 11.9s
# 256:	total: 4.12s	remaining: 11.9s
# 257:	total: 4.13s	remaining: 11.9s
# 258:	total: 4.14s	remaining: 11.9s
# 259:	total: 4.2s	remaining: 12s
# 260:	total: 4.2s	remaining: 11.9s
# 261:	total: 4.21s	remaining: 11.9s
# 262:	total: 4.21s	remaining: 11.8s
# 263:	total: 4.3s	remaining: 12s
# 264:	total: 4.3s	remaining: 11.9s
# 265:	total: 4.3s	remaining: 11.9s
# 266:	total: 4.3s	remaining: 11.8s
# 267:	total: 4.31s	remaining: 11.8s
# 268:	total: 4.32s	remaining: 11.7s
# 269:	total: 4.39s	remaining: 11.9s
# 270:	total: 4.4s	remaining: 11.8s
# 271:	total: 4.4s	remaining: 11.8s
# 272:	total: 4.4s	remaining: 11.7s
# 273:	total: 4.4s	remaining: 11.7s
# 274:	total: 4.41s	remaining: 11.6s
# 275:	total: 4.49s	remaining: 11.8s
# 276:	total: 4.49s	remaining: 11.7s
# 277:	total: 4.5s	remaining: 11.7s
# 278:	total: 4.5s	remaining: 11.6s
# 279:	total: 4.5s	remaining: 11.6s
# 280:	total: 4.51s	remaining: 11.5s
# 281:	total: 4.59s	remaining: 11.7s
# 282:	total: 4.59s	remaining: 11.6s
# 283:	total: 4.59s	remaining: 11.6s
# 284:	total: 4.59s	remaining: 11.5s
# 285:	total: 4.6s	remaining: 11.5s
# 286:	total: 4.61s	remaining: 11.5s
# 287:	total: 4.68s	remaining: 11.6s
# 288:	total: 4.69s	remaining: 11.5s
# 289:	total: 4.69s	remaining: 11.5s
# 290:	total: 4.69s	remaining: 11.4s
# 291:	total: 4.7s	remaining: 11.4s
# 292:	total: 4.7s	remaining: 11.3s
# 293:	total: 4.78s	remaining: 11.5s
# 294:	total: 4.79s	remaining: 11.4s
# 295:	total: 4.79s	remaining: 11.4s
# 296:	total: 4.79s	remaining: 11.3s
# 297:	total: 4.79s	remaining: 11.3s
# 298:	total: 4.8s	remaining: 11.3s
# 299:	total: 4.88s	remaining: 11.4s
# 300:	total: 4.88s	remaining: 11.3s
# 301:	total: 4.88s	remaining: 11.3s
# 302:	total: 4.89s	remaining: 11.2s
# 303:	total: 4.89s	remaining: 11.2s
# 304:	total: 4.97s	remaining: 11.3s
# 305:	total: 4.97s	remaining: 11.3s
# 306:	total: 4.98s	remaining: 11.2s
# 307:	total: 4.98s	remaining: 11.2s
# 308:	total: 4.98s	remaining: 11.1s
# 309:	total: 4.99s	remaining: 11.1s
# 310:	total: 4.99s	remaining: 11.1s
# 311:	total: 5.07s	remaining: 11.2s
# 312:	total: 5.08s	remaining: 11.1s
# 313:	total: 5.08s	remaining: 11.1s
# 314:	total: 5.08s	remaining: 11s
# 315:	total: 5.08s	remaining: 11s
# 316:	total: 5.09s	remaining: 11s
# 317:	total: 5.17s	remaining: 11.1s
# 318:	total: 5.17s	remaining: 11s
# 319:	total: 5.17s	remaining: 11s
# 320:	total: 5.17s	remaining: 10.9s
# 321:	total: 5.18s	remaining: 10.9s
# 322:	total: 5.19s	remaining: 10.9s
# 323:	total: 5.26s	remaining: 11s
# 324:	total: 5.27s	remaining: 10.9s
# 325:	total: 5.27s	remaining: 10.9s
# 326:	total: 5.28s	remaining: 10.9s
# 327:	total: 5.28s	remaining: 10.8s
# 328:	total: 5.29s	remaining: 10.8s
# 329:	total: 5.36s	remaining: 10.9s
# 330:	total: 5.36s	remaining: 10.8s
# 331:	total: 5.37s	remaining: 10.8s
# 332:	total: 5.37s	remaining: 10.8s
# 333:	total: 5.37s	remaining: 10.7s
# 334:	total: 5.38s	remaining: 10.7s
# 335:	total: 5.46s	remaining: 10.8s
# 336:	total: 5.46s	remaining: 10.7s
# 337:	total: 5.46s	remaining: 10.7s
# 338:	total: 5.47s	remaining: 10.7s
# 339:	total: 5.47s	remaining: 10.6s
# 340:	total: 5.48s	remaining: 10.6s
# 341:	total: 5.55s	remaining: 10.7s
# 342:	total: 5.56s	remaining: 10.6s
# 343:	total: 5.56s	remaining: 10.6s
# 344:	total: 5.56s	remaining: 10.6s
# 345:	total: 5.57s	remaining: 10.5s
# 346:	total: 5.57s	remaining: 10.5s
# 347:	total: 5.65s	remaining: 10.6s
# 348:	total: 5.66s	remaining: 10.5s
# 349:	total: 5.66s	remaining: 10.5s
# 350:	total: 5.66s	remaining: 10.5s
# 351:	total: 5.66s	remaining: 10.4s
# 352:	total: 5.67s	remaining: 10.4s
# 353:	total: 5.75s	remaining: 10.5s
# 354:	total: 5.75s	remaining: 10.4s
# 355:	total: 5.75s	remaining: 10.4s
# 356:	total: 5.76s	remaining: 10.4s
# 357:	total: 5.76s	remaining: 10.3s
# 358:	total: 5.77s	remaining: 10.3s
# 359:	total: 5.85s	remaining: 10.4s
# 360:	total: 5.85s	remaining: 10.4s
# 361:	total: 5.85s	remaining: 10.3s
# 362:	total: 5.85s	remaining: 10.3s
# 363:	total: 5.86s	remaining: 10.2s
# 364:	total: 5.87s	remaining: 10.2s
# 365:	total: 5.94s	remaining: 10.3s
# 366:	total: 5.95s	remaining: 10.3s
# 367:	total: 5.95s	remaining: 10.2s
# 368:	total: 5.95s	remaining: 10.2s
# 369:	total: 5.95s	remaining: 10.1s
# 370:	total: 5.96s	remaining: 10.1s
# 371:	total: 6.04s	remaining: 10.2s
# 372:	total: 6.04s	remaining: 10.2s
# 373:	total: 6.04s	remaining: 10.1s
# 374:	total: 6.05s	remaining: 10.1s
# 375:	total: 6.05s	remaining: 10s
# 376:	total: 6.06s	remaining: 10s
# 377:	total: 6.14s	remaining: 10.1s
# 378:	total: 6.14s	remaining: 10.1s
# 379:	total: 6.14s	remaining: 10s
# 380:	total: 6.15s	remaining: 9.99s
# 381:	total: 6.15s	remaining: 9.95s
# 382:	total: 6.24s	remaining: 10s
# 383:	total: 6.24s	remaining: 10s
# 384:	total: 6.24s	remaining: 9.97s
# 385:	total: 6.24s	remaining: 9.93s
# 386:	total: 6.25s	remaining: 9.89s
# 387:	total: 6.25s	remaining: 9.86s
# 388:	total: 6.33s	remaining: 9.94s
# 389:	total: 6.33s	remaining: 9.91s
# 390:	total: 6.34s	remaining: 9.87s
# 391:	total: 6.34s	remaining: 9.84s
# 392:	total: 6.35s	remaining: 9.8s
# 393:	total: 6.43s	remaining: 9.89s
# 394:	total: 6.43s	remaining: 9.85s
# 395:	total: 6.43s	remaining: 9.81s
# 396:	total: 6.44s	remaining: 9.78s
# 397:	total: 6.44s	remaining: 9.74s
# 398:	total: 6.45s	remaining: 9.71s
# 399:	total: 6.53s	remaining: 9.79s
# 400:	total: 6.53s	remaining: 9.75s
# 401:	total: 6.53s	remaining: 9.72s
# 402:	total: 6.54s	remaining: 9.69s
# 403:	total: 6.54s	remaining: 9.65s
# 404:	total: 6.62s	remaining: 9.73s
# 405:	total: 6.63s	remaining: 9.7s
# 406:	total: 6.63s	remaining: 9.66s
# 407:	total: 6.63s	remaining: 9.62s
# 408:	total: 6.63s	remaining: 9.59s
# 409:	total: 6.64s	remaining: 9.56s
# 410:	total: 6.72s	remaining: 9.63s
# 411:	total: 6.72s	remaining: 9.6s
# 412:	total: 6.73s	remaining: 9.56s
# 413:	total: 6.73s	remaining: 9.53s
# 414:	total: 6.73s	remaining: 9.49s
# 415:	total: 6.74s	remaining: 9.47s
# 416:	total: 6.82s	remaining: 9.53s
# 417:	total: 6.82s	remaining: 9.5s
# 418:	total: 6.83s	remaining: 9.46s
# 419:	total: 6.83s	remaining: 9.43s
# 420:	total: 6.83s	remaining: 9.39s
# 421:	total: 6.84s	remaining: 9.37s
# 422:	total: 6.92s	remaining: 9.43s
# 423:	total: 6.92s	remaining: 9.4s
# 424:	total: 6.92s	remaining: 9.36s
# 425:	total: 6.92s	remaining: 9.33s
# 426:	total: 6.93s	remaining: 9.3s
# 427:	total: 6.94s	remaining: 9.27s
# 428:	total: 7.01s	remaining: 9.33s
# 429:	total: 7.02s	remaining: 9.3s
# 430:	total: 7.02s	remaining: 9.27s
# 431:	total: 7.03s	remaining: 9.24s
# 432:	total: 7.03s	remaining: 9.21s
# 433:	total: 7.11s	remaining: 9.27s
# 434:	total: 7.11s	remaining: 9.24s
# 435:	total: 7.12s	remaining: 9.2s
# 436:	total: 7.12s	remaining: 9.17s
# 437:	total: 7.12s	remaining: 9.14s
# 438:	total: 7.13s	remaining: 9.11s
# 439:	total: 7.21s	remaining: 9.17s
# 440:	total: 7.21s	remaining: 9.14s
# 441:	total: 7.21s	remaining: 9.1s
# 442:	total: 7.21s	remaining: 9.07s
# 443:	total: 7.22s	remaining: 9.04s
# 444:	total: 7.23s	remaining: 9.01s
# 445:	total: 7.3s	remaining: 9.07s
# 446:	total: 7.3s	remaining: 9.04s
# 447:	total: 7.31s	remaining: 9.01s
# 448:	total: 7.31s	remaining: 8.97s
# 449:	total: 7.31s	remaining: 8.94s
# 450:	total: 7.32s	remaining: 8.91s
# 451:	total: 7.4s	remaining: 8.97s
# 452:	total: 7.4s	remaining: 8.94s
# 453:	total: 7.41s	remaining: 8.91s
# 454:	total: 7.41s	remaining: 8.88s
# 455:	total: 7.42s	remaining: 8.85s
# 456:	total: 7.5s	remaining: 8.9s
# 457:	total: 7.5s	remaining: 8.87s
# 458:	total: 7.5s	remaining: 8.84s
# 459:	total: 7.5s	remaining: 8.81s
# 460:	total: 7.51s	remaining: 8.78s
# 461:	total: 7.51s	remaining: 8.75s
# 462:	total: 7.59s	remaining: 8.8s
# 463:	total: 7.59s	remaining: 8.77s
# 464:	total: 7.6s	remaining: 8.74s
# 465:	total: 7.6s	remaining: 8.71s
# 466:	total: 7.6s	remaining: 8.68s
# 467:	total: 7.61s	remaining: 8.65s
# 468:	total: 7.69s	remaining: 8.7s
# 469:	total: 7.69s	remaining: 8.67s
# 470:	total: 7.69s	remaining: 8.64s
# 471:	total: 7.7s	remaining: 8.61s
# 472:	total: 7.7s	remaining: 8.58s
# 473:	total: 7.71s	remaining: 8.55s
# 474:	total: 7.78s	remaining: 8.6s
# 475:	total: 7.79s	remaining: 8.57s
# 476:	total: 7.79s	remaining: 8.54s
# 477:	total: 7.79s	remaining: 8.51s
# 478:	total: 7.79s	remaining: 8.48s
# 479:	total: 7.81s	remaining: 8.46s
# 480:	total: 7.88s	remaining: 8.5s
# 481:	total: 7.88s	remaining: 8.47s
# 482:	total: 7.89s	remaining: 8.44s
# 483:	total: 7.89s	remaining: 8.41s
# 484:	total: 7.89s	remaining: 8.38s
# 485:	total: 7.9s	remaining: 8.35s
# 486:	total: 7.98s	remaining: 8.4s
# 487:	total: 7.98s	remaining: 8.37s
# 488:	total: 7.98s	remaining: 8.34s
# 489:	total: 7.99s	remaining: 8.31s
# 490:	total: 7.99s	remaining: 8.28s
# 491:	total: 8s	remaining: 8.26s
# 492:	total: 8.08s	remaining: 8.3s
# 493:	total: 8.08s	remaining: 8.28s
# 494:	total: 8.09s	remaining: 8.25s
# 495:	total: 8.17s	remaining: 8.31s
# 496:	total: 8.18s	remaining: 8.28s
# 497:	total: 8.18s	remaining: 8.24s
# 498:	total: 8.18s	remaining: 8.21s
# 499:	total: 8.19s	remaining: 8.19s
# 500:	total: 8.19s	remaining: 8.16s
# 501:	total: 8.27s	remaining: 8.21s
# 502:	total: 8.27s	remaining: 8.18s
# 503:	total: 8.28s	remaining: 8.15s
# 504:	total: 8.28s	remaining: 8.12s
# 505:	total: 8.28s	remaining: 8.09s
# 506:	total: 8.29s	remaining: 8.06s
# 507:	total: 8.37s	remaining: 8.11s
# 508:	total: 8.37s	remaining: 8.07s
# 509:	total: 8.37s	remaining: 8.04s
# 510:	total: 8.38s	remaining: 8.02s
# 511:	total: 8.38s	remaining: 7.99s
# 512:	total: 8.39s	remaining: 7.96s
# 513:	total: 8.47s	remaining: 8.01s
# 514:	total: 8.47s	remaining: 7.97s
# 515:	total: 8.47s	remaining: 7.95s
# 516:	total: 8.48s	remaining: 7.92s
# 517:	total: 8.48s	remaining: 7.89s
# 518:	total: 8.56s	remaining: 7.94s
# 519:	total: 8.57s	remaining: 7.91s
# 520:	total: 8.57s	remaining: 7.88s
# 521:	total: 8.57s	remaining: 7.85s
# 522:	total: 8.57s	remaining: 7.82s
# 523:	total: 8.58s	remaining: 7.8s
# 524:	total: 8.66s	remaining: 7.83s
# 525:	total: 8.66s	remaining: 7.81s
# 526:	total: 8.66s	remaining: 7.78s
# 527:	total: 8.67s	remaining: 7.75s
# 528:	total: 8.68s	remaining: 7.72s
# 529:	total: 8.76s	remaining: 7.77s
# 530:	total: 8.76s	remaining: 7.74s
# 531:	total: 8.76s	remaining: 7.71s
# 532:	total: 8.77s	remaining: 7.68s
# 533:	total: 8.77s	remaining: 7.65s
# 534:	total: 8.78s	remaining: 7.63s
# 535:	total: 8.86s	remaining: 7.67s
# 536:	total: 8.86s	remaining: 7.64s
# 537:	total: 8.86s	remaining: 7.61s
# 538:	total: 8.86s	remaining: 7.58s
# 539:	total: 8.87s	remaining: 7.55s
# 540:	total: 8.87s	remaining: 7.53s
# 541:	total: 8.95s	remaining: 7.57s
# 542:	total: 8.96s	remaining: 7.54s
# 543:	total: 8.96s	remaining: 7.51s
# 544:	total: 8.96s	remaining: 7.48s
# 545:	total: 8.96s	remaining: 7.45s
# 546:	total: 8.97s	remaining: 7.43s
# 547:	total: 9.05s	remaining: 7.46s
# 548:	total: 9.05s	remaining: 7.44s
# 549:	total: 9.05s	remaining: 7.41s
# 550:	total: 9.06s	remaining: 7.38s
# 551:	total: 9.06s	remaining: 7.35s
# 552:	total: 9.06s	remaining: 7.33s
# 553:	total: 9.15s	remaining: 7.36s
# 554:	total: 9.15s	remaining: 7.34s
# 555:	total: 9.15s	remaining: 7.31s
# 556:	total: 9.15s	remaining: 7.28s
# 557:	total: 9.16s	remaining: 7.25s
# 558:	total: 9.16s	remaining: 7.23s
# 559:	total: 9.24s	remaining: 7.26s
# 560:	total: 9.25s	remaining: 7.24s
# 561:	total: 9.25s	remaining: 7.21s
# 562:	total: 9.25s	remaining: 7.18s
# 563:	total: 9.25s	remaining: 7.15s
# 564:	total: 9.26s	remaining: 7.13s
# 565:	total: 9.34s	remaining: 7.16s
# 566:	total: 9.34s	remaining: 7.13s
# 567:	total: 9.35s	remaining: 7.11s
# 568:	total: 9.35s	remaining: 7.08s
# 569:	total: 9.35s	remaining: 7.05s
# 570:	total: 9.36s	remaining: 7.03s
# 571:	total: 9.44s	remaining: 7.06s
# 572:	total: 9.44s	remaining: 7.03s
# 573:	total: 9.44s	remaining: 7.01s
# 574:	total: 9.45s	remaining: 6.98s
# 575:	total: 9.45s	remaining: 6.95s
# 576:	total: 9.46s	remaining: 6.93s
# 577:	total: 9.53s	remaining: 6.96s
# 578:	total: 9.54s	remaining: 6.93s
# 579:	total: 9.54s	remaining: 6.91s
# 580:	total: 9.54s	remaining: 6.88s
# 581:	total: 9.54s	remaining: 6.86s
# 582:	total: 9.55s	remaining: 6.83s
# 583:	total: 9.63s	remaining: 6.86s
# 584:	total: 9.63s	remaining: 6.83s
# 585:	total: 9.64s	remaining: 6.81s
# 586:	total: 9.64s	remaining: 6.78s
# 587:	total: 9.64s	remaining: 6.75s
# 588:	total: 9.64s	remaining: 6.73s
# 589:	total: 9.65s	remaining: 6.71s
# 590:	total: 9.73s	remaining: 6.73s
# 591:	total: 9.73s	remaining: 6.7s
# 592:	total: 9.73s	remaining: 6.68s
# 593:	total: 9.73s	remaining: 6.65s
# 594:	total: 9.74s	remaining: 6.63s
# 595:	total: 9.74s	remaining: 6.61s
# 596:	total: 9.82s	remaining: 6.63s
# 597:	total: 9.82s	remaining: 6.61s
# 598:	total: 9.83s	remaining: 6.58s
# 599:	total: 9.83s	remaining: 6.55s
# 600:	total: 9.83s	remaining: 6.53s
# 601:	total: 9.84s	remaining: 6.5s
# 602:	total: 9.84s	remaining: 6.48s
# 603:	total: 9.92s	remaining: 6.5s
# 604:	total: 9.92s	remaining: 6.48s
# 605:	total: 9.93s	remaining: 6.45s
# 606:	total: 9.93s	remaining: 6.43s
# 607:	total: 9.93s	remaining: 6.4s
# 608:	total: 9.94s	remaining: 6.38s
# 609:	total: 10s	remaining: 6.4s
# 610:	total: 10s	remaining: 6.38s
# 611:	total: 10s	remaining: 6.35s
# 612:	total: 10s	remaining: 6.33s
# 613:	total: 10s	remaining: 6.3s
# 614:	total: 10s	remaining: 6.28s
# 615:	total: 10.1s	remaining: 6.3s
# 616:	total: 10.1s	remaining: 6.28s
# 617:	total: 10.1s	remaining: 6.25s
# 618:	total: 10.1s	remaining: 6.23s
# 619:	total: 10.1s	remaining: 6.2s
# 620:	total: 10.1s	remaining: 6.18s
# 621:	total: 10.1s	remaining: 6.16s
# 622:	total: 10.2s	remaining: 6.18s
# 623:	total: 10.2s	remaining: 6.15s
# 624:	total: 10.2s	remaining: 6.13s
# 625:	total: 10.2s	remaining: 6.1s
# 626:	total: 10.2s	remaining: 6.08s
# 627:	total: 10.2s	remaining: 6.05s
# 628:	total: 10.2s	remaining: 6.03s
# 629:	total: 10.3s	remaining: 6.05s
# 630:	total: 10.3s	remaining: 6.03s
# 631:	total: 10.3s	remaining: 6s
# 632:	total: 10.3s	remaining: 5.98s
# 633:	total: 10.3s	remaining: 5.96s
# 634:	total: 10.3s	remaining: 5.93s
# 635:	total: 10.4s	remaining: 5.95s
# 636:	total: 10.4s	remaining: 5.93s
# 637:	total: 10.4s	remaining: 5.9s
# 638:	total: 10.4s	remaining: 5.88s
# 639:	total: 10.4s	remaining: 5.86s
# 640:	total: 10.4s	remaining: 5.83s
# 641:	total: 10.4s	remaining: 5.81s
# 642:	total: 10.5s	remaining: 5.83s
# 643:	total: 10.5s	remaining: 5.8s
# 644:	total: 10.5s	remaining: 5.78s
# 645:	total: 10.5s	remaining: 5.76s
# 646:	total: 10.5s	remaining: 5.73s
# 647:	total: 10.5s	remaining: 5.71s
# 648:	total: 10.5s	remaining: 5.69s
# 649:	total: 10.6s	remaining: 5.71s
# 650:	total: 10.6s	remaining: 5.68s
# 651:	total: 10.6s	remaining: 5.66s
# 652:	total: 10.6s	remaining: 5.63s
# 653:	total: 10.6s	remaining: 5.61s
# 654:	total: 10.6s	remaining: 5.59s
# 655:	total: 10.7s	remaining: 5.61s
# 656:	total: 10.7s	remaining: 5.58s
# 657:	total: 10.7s	remaining: 5.56s
# 658:	total: 10.7s	remaining: 5.54s
# 659:	total: 10.7s	remaining: 5.51s
# 660:	total: 10.7s	remaining: 5.5s
# 661:	total: 10.8s	remaining: 5.51s
# 662:	total: 10.8s	remaining: 5.49s
# 663:	total: 10.8s	remaining: 5.46s
# 664:	total: 10.8s	remaining: 5.44s
# 665:	total: 10.8s	remaining: 5.42s
# 666:	total: 10.9s	remaining: 5.43s
# 667:	total: 10.9s	remaining: 5.41s
# 668:	total: 10.9s	remaining: 5.39s
# 669:	total: 10.9s	remaining: 5.37s
# 670:	total: 10.9s	remaining: 5.34s
# 671:	total: 10.9s	remaining: 5.32s
# 672:	total: 11s	remaining: 5.34s
# 673:	total: 11s	remaining: 5.31s
# 674:	total: 11s	remaining: 5.29s
# 675:	total: 11s	remaining: 5.27s
# 676:	total: 11s	remaining: 5.25s
# 677:	total: 11.1s	remaining: 5.26s
# 678:	total: 11.1s	remaining: 5.24s
# 679:	total: 11.1s	remaining: 5.22s
# 680:	total: 11.1s	remaining: 5.2s
# 681:	total: 11.1s	remaining: 5.17s
# 682:	total: 11.1s	remaining: 5.15s
# 683:	total: 11.2s	remaining: 5.16s
# 684:	total: 11.2s	remaining: 5.14s
# 685:	total: 11.2s	remaining: 5.12s
# 686:	total: 11.2s	remaining: 5.1s
# 687:	total: 11.3s	remaining: 5.11s
# 688:	total: 11.3s	remaining: 5.09s
# 689:	total: 11.3s	remaining: 5.07s
# 690:	total: 11.3s	remaining: 5.05s
# 691:	total: 11.3s	remaining: 5.02s
# 692:	total: 11.3s	remaining: 5s
# 693:	total: 11.3s	remaining: 4.98s
# 694:	total: 11.4s	remaining: 4.99s
# 695:	total: 11.4s	remaining: 4.97s
# 696:	total: 11.4s	remaining: 4.95s
# 697:	total: 11.4s	remaining: 4.92s
# 698:	total: 11.4s	remaining: 4.9s
# 699:	total: 11.5s	remaining: 4.92s
# 700:	total: 11.5s	remaining: 4.89s
# 701:	total: 11.5s	remaining: 4.87s
# 702:	total: 11.5s	remaining: 4.85s
# 703:	total: 11.5s	remaining: 4.83s
# 704:	total: 11.5s	remaining: 4.8s
# 705:	total: 11.5s	remaining: 4.79s
# 706:	total: 11.6s	remaining: 4.79s
# 707:	total: 11.6s	remaining: 4.77s
# 708:	total: 11.6s	remaining: 4.75s
# 709:	total: 11.6s	remaining: 4.73s
# 710:	total: 11.6s	remaining: 4.71s
# 711:	total: 11.6s	remaining: 4.69s
# 712:	total: 11.7s	remaining: 4.69s
# 713:	total: 11.7s	remaining: 4.67s
# 714:	total: 11.7s	remaining: 4.65s
# 715:	total: 11.7s	remaining: 4.63s
# 716:	total: 11.7s	remaining: 4.61s
# 717:	total: 11.7s	remaining: 4.59s
# 718:	total: 11.8s	remaining: 4.6s
# 719:	total: 11.8s	remaining: 4.57s
# 720:	total: 11.8s	remaining: 4.55s
# 721:	total: 11.8s	remaining: 4.53s
# 722:	total: 11.8s	remaining: 4.51s
# 723:	total: 11.9s	remaining: 4.52s
# 724:	total: 11.9s	remaining: 4.5s
# 725:	total: 11.9s	remaining: 4.48s
# 726:	total: 11.9s	remaining: 4.46s
# 727:	total: 11.9s	remaining: 4.43s
# 728:	total: 11.9s	remaining: 4.42s
# 729:	total: 12s	remaining: 4.42s
# 730:	total: 12s	remaining: 4.4s
# 731:	total: 12s	remaining: 4.38s
# 732:	total: 12s	remaining: 4.36s
# 733:	total: 12s	remaining: 4.34s
# 734:	total: 12s	remaining: 4.32s
# 735:	total: 12.1s	remaining: 4.32s
# 736:	total: 12.1s	remaining: 4.3s
# 737:	total: 12.1s	remaining: 4.28s
# 738:	total: 12.1s	remaining: 4.26s
# 739:	total: 12.1s	remaining: 4.24s
# 740:	total: 12.1s	remaining: 4.25s
# 741:	total: 12.2s	remaining: 4.22s
# 742:	total: 12.2s	remaining: 4.2s
# 743:	total: 12.2s	remaining: 4.18s
# 744:	total: 12.2s	remaining: 4.16s
# 745:	total: 12.2s	remaining: 4.14s
# 746:	total: 12.2s	remaining: 4.12s
# 747:	total: 12.2s	remaining: 4.13s
# 748:	total: 12.2s	remaining: 4.1s
# 749:	total: 12.3s	remaining: 4.08s
# 750:	total: 12.3s	remaining: 4.06s
# 751:	total: 12.3s	remaining: 4.04s
# 752:	total: 12.3s	remaining: 4.03s
# 753:	total: 12.3s	remaining: 4.03s
# 754:	total: 12.3s	remaining: 4.01s
# 755:	total: 12.3s	remaining: 3.98s
# 756:	total: 12.4s	remaining: 3.96s
# 757:	total: 12.4s	remaining: 3.94s
# 758:	total: 12.4s	remaining: 3.92s
# 759:	total: 12.4s	remaining: 3.93s
# 760:	total: 12.4s	remaining: 3.91s
# 761:	total: 12.4s	remaining: 3.89s
# 762:	total: 12.4s	remaining: 3.87s
# 763:	total: 12.5s	remaining: 3.85s
# 764:	total: 12.5s	remaining: 3.85s
# 765:	total: 12.5s	remaining: 3.83s
# 766:	total: 12.5s	remaining: 3.81s
# 767:	total: 12.5s	remaining: 3.79s
# 768:	total: 12.5s	remaining: 3.77s
# 769:	total: 12.6s	remaining: 3.75s
# 770:	total: 12.6s	remaining: 3.75s
# 771:	total: 12.6s	remaining: 3.73s
# 772:	total: 12.6s	remaining: 3.71s
# 773:	total: 12.6s	remaining: 3.69s
# 774:	total: 12.6s	remaining: 3.67s
# 775:	total: 12.7s	remaining: 3.67s
# 776:	total: 12.7s	remaining: 3.65s
# 777:	total: 12.7s	remaining: 3.63s
# 778:	total: 12.7s	remaining: 3.61s
# 779:	total: 12.7s	remaining: 3.59s
# 780:	total: 12.7s	remaining: 3.57s
# 781:	total: 12.8s	remaining: 3.58s
# 782:	total: 12.8s	remaining: 3.56s
# 783:	total: 12.8s	remaining: 3.54s
# 784:	total: 12.8s	remaining: 3.52s
# 785:	total: 12.8s	remaining: 3.5s
# 786:	total: 12.9s	remaining: 3.5s
# 787:	total: 12.9s	remaining: 3.48s
# 788:	total: 12.9s	remaining: 3.46s
# 789:	total: 12.9s	remaining: 3.44s
# 790:	total: 12.9s	remaining: 3.42s
# 791:	total: 12.9s	remaining: 3.4s
# 792:	total: 13s	remaining: 3.4s
# 793:	total: 13s	remaining: 3.38s
# 794:	total: 13s	remaining: 3.36s
# 795:	total: 13s	remaining: 3.34s
# 796:	total: 13s	remaining: 3.32s
# 797:	total: 13s	remaining: 3.3s
# 798:	total: 13.1s	remaining: 3.3s
# 799:	total: 13.1s	remaining: 3.28s
# 800:	total: 13.1s	remaining: 3.26s
# 801:	total: 13.1s	remaining: 3.24s
# 802:	total: 13.2s	remaining: 3.24s
# 803:	total: 13.2s	remaining: 3.22s
# 804:	total: 13.2s	remaining: 3.2s
# 805:	total: 13.2s	remaining: 3.18s
# 806:	total: 13.2s	remaining: 3.16s
# 807:	total: 13.2s	remaining: 3.14s
# 808:	total: 13.2s	remaining: 3.12s
# 809:	total: 13.3s	remaining: 3.12s
# 810:	total: 13.3s	remaining: 3.1s
# 811:	total: 13.3s	remaining: 3.08s
# 812:	total: 13.3s	remaining: 3.06s
# 813:	total: 13.3s	remaining: 3.04s
# 814:	total: 13.3s	remaining: 3.02s
# 815:	total: 13.4s	remaining: 3.02s
# 816:	total: 13.4s	remaining: 3s
# 817:	total: 13.4s	remaining: 2.98s
# 818:	total: 13.4s	remaining: 2.96s
# 819:	total: 13.4s	remaining: 2.95s
# 820:	total: 13.5s	remaining: 2.94s
# 821:	total: 13.5s	remaining: 2.92s
# 822:	total: 13.5s	remaining: 2.9s
# 823:	total: 13.5s	remaining: 2.89s
# 824:	total: 13.5s	remaining: 2.87s
# 825:	total: 13.6s	remaining: 2.86s
# 826:	total: 13.6s	remaining: 2.84s
# 827:	total: 13.6s	remaining: 2.83s
# 828:	total: 13.6s	remaining: 2.81s
# 829:	total: 13.6s	remaining: 2.79s
# 830:	total: 13.6s	remaining: 2.77s
# 831:	total: 13.7s	remaining: 2.77s
# 832:	total: 13.7s	remaining: 2.75s
# 833:	total: 13.7s	remaining: 2.73s
# 834:	total: 13.7s	remaining: 2.71s
# 835:	total: 13.7s	remaining: 2.69s
# 836:	total: 13.7s	remaining: 2.67s
# 837:	total: 13.8s	remaining: 2.67s
# 838:	total: 13.8s	remaining: 2.65s
# 839:	total: 13.8s	remaining: 2.63s
# 840:	total: 13.8s	remaining: 2.61s
# 841:	total: 13.9s	remaining: 2.61s
# 842:	total: 13.9s	remaining: 2.59s
# 843:	total: 13.9s	remaining: 2.57s
# 844:	total: 13.9s	remaining: 2.55s
# 845:	total: 14s	remaining: 2.55s
# 846:	total: 14s	remaining: 2.53s
# 847:	total: 14s	remaining: 2.51s
# 848:	total: 14s	remaining: 2.49s
# 849:	total: 14.1s	remaining: 2.48s
# 850:	total: 14.1s	remaining: 2.47s
# 851:	total: 14.1s	remaining: 2.45s
# 852:	total: 14.1s	remaining: 2.43s
# 853:	total: 14.1s	remaining: 2.41s
# 854:	total: 14.2s	remaining: 2.4s
# 855:	total: 14.2s	remaining: 2.39s
# 856:	total: 14.2s	remaining: 2.37s
# 857:	total: 14.2s	remaining: 2.35s
# 858:	total: 14.3s	remaining: 2.34s
# 859:	total: 14.3s	remaining: 2.32s
# 860:	total: 14.3s	remaining: 2.31s
# 861:	total: 14.3s	remaining: 2.29s
# 862:	total: 14.3s	remaining: 2.27s
# 863:	total: 14.4s	remaining: 2.26s
# 864:	total: 14.4s	remaining: 2.24s
# 865:	total: 14.4s	remaining: 2.23s
# 866:	total: 14.4s	remaining: 2.21s
# 867:	total: 14.5s	remaining: 2.2s
# 868:	total: 14.5s	remaining: 2.18s
# 869:	total: 14.5s	remaining: 2.16s
# 870:	total: 14.5s	remaining: 2.15s
# 871:	total: 14.5s	remaining: 2.13s
# 872:	total: 14.6s	remaining: 2.12s
# 873:	total: 14.6s	remaining: 2.1s
# 874:	total: 14.6s	remaining: 2.08s
# 875:	total: 14.6s	remaining: 2.06s
# 876:	total: 14.6s	remaining: 2.05s
# 877:	total: 14.7s	remaining: 2.04s
# 878:	total: 14.7s	remaining: 2.02s
# 879:	total: 14.7s	remaining: 2s
# 880:	total: 14.7s	remaining: 1.98s
# 881:	total: 14.7s	remaining: 1.96s
# 882:	total: 14.7s	remaining: 1.95s
# 883:	total: 14.8s	remaining: 1.94s
# 884:	total: 14.8s	remaining: 1.92s
# 885:	total: 14.8s	remaining: 1.9s
# 886:	total: 14.8s	remaining: 1.88s
# 887:	total: 14.8s	remaining: 1.86s
# 888:	total: 14.9s	remaining: 1.85s
# 889:	total: 14.9s	remaining: 1.84s
# 890:	total: 14.9s	remaining: 1.82s
# 891:	total: 14.9s	remaining: 1.8s
# 892:	total: 14.9s	remaining: 1.78s
# 893:	total: 14.9s	remaining: 1.76s
# 894:	total: 15s	remaining: 1.75s
# 895:	total: 15s	remaining: 1.74s
# 896:	total: 15s	remaining: 1.72s
# 897:	total: 15s	remaining: 1.7s
# 898:	total: 15s	remaining: 1.68s
# 899:	total: 15s	remaining: 1.66s
# 900:	total: 15.1s	remaining: 1.65s
# 901:	total: 15.1s	remaining: 1.64s
# 902:	total: 15.1s	remaining: 1.62s
# 903:	total: 15.1s	remaining: 1.6s
# 904:	total: 15.1s	remaining: 1.58s
# 905:	total: 15.1s	remaining: 1.56s
# 906:	total: 15.1s	remaining: 1.55s
# 907:	total: 15.2s	remaining: 1.53s
# 908:	total: 15.2s	remaining: 1.52s
# 909:	total: 15.2s	remaining: 1.5s
# 910:	total: 15.2s	remaining: 1.48s
# 911:	total: 15.2s	remaining: 1.47s
# 912:	total: 15.3s	remaining: 1.45s
# 913:	total: 15.3s	remaining: 1.44s
# 914:	total: 15.3s	remaining: 1.42s
# 915:	total: 15.3s	remaining: 1.4s
# 916:	total: 15.3s	remaining: 1.38s
# 917:	total: 15.3s	remaining: 1.37s
# 918:	total: 15.3s	remaining: 1.35s
# 919:	total: 15.3s	remaining: 1.33s
# 920:	total: 15.4s	remaining: 1.32s
# 921:	total: 15.4s	remaining: 1.3s
# 922:	total: 15.4s	remaining: 1.29s
# 923:	total: 15.4s	remaining: 1.27s
# 924:	total: 15.4s	remaining: 1.25s
# 925:	total: 15.5s	remaining: 1.23s
# 926:	total: 15.5s	remaining: 1.22s
# 927:	total: 15.5s	remaining: 1.21s
# 928:	total: 15.5s	remaining: 1.19s
# 929:	total: 15.5s	remaining: 1.17s
# 930:	total: 15.5s	remaining: 1.15s
# 931:	total: 15.6s	remaining: 1.13s
# 932:	total: 15.6s	remaining: 1.12s
# 933:	total: 15.6s	remaining: 1.1s
# 934:	total: 15.6s	remaining: 1.09s
# 935:	total: 15.6s	remaining: 1.07s
# 936:	total: 15.7s	remaining: 1.06s
# 937:	total: 15.7s	remaining: 1.04s
# 938:	total: 15.7s	remaining: 1.02s
# 939:	total: 15.7s	remaining: 1s
# 940:	total: 15.7s	remaining: 987ms
# 941:	total: 15.7s	remaining: 970ms
# 942:	total: 15.8s	remaining: 957ms
# 943:	total: 15.8s	remaining: 939ms
# 944:	total: 15.8s	remaining: 921ms
# 945:	total: 15.8s	remaining: 904ms
# 946:	total: 15.8s	remaining: 886ms
# 947:	total: 15.8s	remaining: 869ms
# 948:	total: 15.9s	remaining: 856ms
# 949:	total: 15.9s	remaining: 838ms
# 950:	total: 15.9s	remaining: 821ms
# 951:	total: 15.9s	remaining: 803ms
# 952:	total: 15.9s	remaining: 786ms
# 953:	total: 16s	remaining: 772ms
# 954:	total: 16s	remaining: 755ms
# 955:	total: 16s	remaining: 737ms
# 956:	total: 16s	remaining: 720ms
# 957:	total: 16s	remaining: 703ms
# 958:	total: 16s	remaining: 686ms
# 959:	total: 16.1s	remaining: 671ms
# 960:	total: 16.1s	remaining: 654ms
# 961:	total: 16.1s	remaining: 637ms
# 962:	total: 16.1s	remaining: 619ms
# 963:	total: 16.1s	remaining: 602ms
# 964:	total: 16.1s	remaining: 585ms
# 965:	total: 16.1s	remaining: 568ms
# 966:	total: 16.2s	remaining: 553ms
# 967:	total: 16.2s	remaining: 536ms
# 968:	total: 16.2s	remaining: 519ms
# 969:	total: 16.2s	remaining: 502ms
# 970:	total: 16.2s	remaining: 484ms
# 971:	total: 16.2s	remaining: 468ms
# 972:	total: 16.3s	remaining: 453ms
# 973:	total: 16.3s	remaining: 435ms
# 974:	total: 16.3s	remaining: 418ms
# 975:	total: 16.3s	remaining: 401ms
# 976:	total: 16.3s	remaining: 384ms
# 977:	total: 16.3s	remaining: 367ms
# 978:	total: 16.3s	remaining: 350ms
# 979:	total: 16.4s	remaining: 335ms
# 980:	total: 16.4s	remaining: 318ms
# 981:	total: 16.4s	remaining: 301ms
# 982:	total: 16.4s	remaining: 284ms
# 983:	total: 16.4s	remaining: 267ms
# 984:	total: 16.4s	remaining: 250ms
# 985:	total: 16.5s	remaining: 234ms
# 986:	total: 16.5s	remaining: 217ms
# 987:	total: 16.5s	remaining: 200ms
# 988:	total: 16.5s	remaining: 184ms
# 989:	total: 16.5s	remaining: 167ms
# 990:	total: 16.5s	remaining: 150ms
# 991:	total: 16.6s	remaining: 134ms
# 992:	total: 16.6s	remaining: 117ms
# 993:	total: 16.6s	remaining: 100ms
# 994:	total: 16.6s	remaining: 83.5ms
# 995:	total: 16.7s	remaining: 67.1ms
# 996:	total: 16.7s	remaining: 50.2ms
# 997:	total: 16.7s	remaining: 33.5ms
# 998:	total: 16.7s	remaining: 16.7ms
# 999:	total: 16.8s	remaining: 0us
# 0:	total: 2.63ms	remaining: 2.62s
# 1:	total: 5.44ms	remaining: 2.71s
# 2:	total: 7.93ms	remaining: 2.64s
# 3:	total: 10.4ms	remaining: 2.58s
# 4:	total: 15.8ms	remaining: 3.14s
# 5:	total: 75.3ms	remaining: 12.5s
# 6:	total: 80.2ms	remaining: 11.4s
# 7:	total: 83.7ms	remaining: 10.4s
# 8:	total: 89ms	remaining: 9.8s
# 9:	total: 174ms	remaining: 17.2s
# 10:	total: 176ms	remaining: 15.8s
# 11:	total: 179ms	remaining: 14.7s
# 12:	total: 182ms	remaining: 13.8s
# 13:	total: 185ms	remaining: 13s
# 14:	total: 188ms	remaining: 12.4s
# 15:	total: 270ms	remaining: 16.6s
# 16:	total: 273ms	remaining: 15.8s
# 17:	total: 275ms	remaining: 15s
# 18:	total: 278ms	remaining: 14.3s
# 19:	total: 280ms	remaining: 13.7s
# 20:	total: 288ms	remaining: 13.4s
# 21:	total: 367ms	remaining: 16.3s
# 22:	total: 370ms	remaining: 15.7s
# 23:	total: 373ms	remaining: 15.2s
# 24:	total: 376ms	remaining: 14.7s
# 25:	total: 378ms	remaining: 14.2s
# 26:	total: 386ms	remaining: 13.9s
# 27:	total: 464ms	remaining: 16.1s
# 28:	total: 467ms	remaining: 15.6s
# 29:	total: 470ms	remaining: 15.2s
# 30:	total: 473ms	remaining: 14.8s
# 31:	total: 476ms	remaining: 14.4s
# 32:	total: 483ms	remaining: 14.2s
# 33:	total: 562ms	remaining: 16s
# 34:	total: 564ms	remaining: 15.6s
# 35:	total: 567ms	remaining: 15.2s
# 36:	total: 569ms	remaining: 14.8s
# 37:	total: 572ms	remaining: 14.5s
# 38:	total: 580ms	remaining: 14.3s
# 39:	total: 659ms	remaining: 15.8s
# 40:	total: 662ms	remaining: 15.5s
# 41:	total: 667ms	remaining: 15.2s
# 42:	total: 670ms	remaining: 14.9s
# 43:	total: 678ms	remaining: 14.7s
# 44:	total: 756ms	remaining: 16.1s
# 45:	total: 759ms	remaining: 15.7s
# 46:	total: 762ms	remaining: 15.4s
# 47:	total: 764ms	remaining: 15.2s
# 48:	total: 767ms	remaining: 14.9s
# 49:	total: 775ms	remaining: 14.7s
# 50:	total: 853ms	remaining: 15.9s
# 51:	total: 856ms	remaining: 15.6s
# 52:	total: 858ms	remaining: 15.3s
# 53:	total: 861ms	remaining: 15.1s
# 54:	total: 863ms	remaining: 14.8s
# 55:	total: 868ms	remaining: 14.6s
# 56:	total: 950ms	remaining: 15.7s
# 57:	total: 952ms	remaining: 15.5s
# 58:	total: 955ms	remaining: 15.2s
# 59:	total: 960ms	remaining: 15s
# 60:	total: 963ms	remaining: 14.8s
# 61:	total: 971ms	remaining: 14.7s
# 62:	total: 1.05s	remaining: 15.6s
# 63:	total: 1.05s	remaining: 15.3s
# 64:	total: 1.05s	remaining: 15.1s
# 65:	total: 1.05s	remaining: 14.9s
# 66:	total: 1.06s	remaining: 14.7s
# 67:	total: 1.14s	remaining: 15.7s
# 68:	total: 1.15s	remaining: 15.4s
# 69:	total: 1.15s	remaining: 15.3s
# 70:	total: 1.15s	remaining: 15.1s
# 71:	total: 1.15s	remaining: 14.9s
# 72:	total: 1.16s	remaining: 14.8s
# 73:	total: 1.24s	remaining: 15.5s
# 74:	total: 1.24s	remaining: 15.3s
# 75:	total: 1.25s	remaining: 15.1s
# 76:	total: 1.25s	remaining: 15s
# 77:	total: 1.25s	remaining: 14.8s
# 78:	total: 1.26s	remaining: 14.7s
# 79:	total: 1.34s	remaining: 15.4s
# 80:	total: 1.34s	remaining: 15.2s
# 81:	total: 1.34s	remaining: 15s
# 82:	total: 1.34s	remaining: 14.9s
# 83:	total: 1.35s	remaining: 14.7s
# 84:	total: 1.35s	remaining: 14.6s
# 85:	total: 1.43s	remaining: 15.2s
# 86:	total: 1.44s	remaining: 15.1s
# 87:	total: 1.44s	remaining: 14.9s
# 88:	total: 1.44s	remaining: 14.8s
# 89:	total: 1.44s	remaining: 14.6s
# 90:	total: 1.45s	remaining: 14.5s
# 91:	total: 1.53s	remaining: 15.1s
# 92:	total: 1.53s	remaining: 14.9s
# 93:	total: 1.54s	remaining: 14.8s
# 94:	total: 1.54s	remaining: 14.7s
# 95:	total: 1.55s	remaining: 14.6s
# 96:	total: 1.63s	remaining: 15.1s
# 97:	total: 1.63s	remaining: 15s
# 98:	total: 1.63s	remaining: 14.8s
# 99:	total: 1.63s	remaining: 14.7s
# 100:	total: 1.64s	remaining: 14.6s
# 101:	total: 1.64s	remaining: 14.5s
# 102:	total: 1.72s	remaining: 15s
# 103:	total: 1.73s	remaining: 14.9s
# 104:	total: 1.73s	remaining: 14.8s
# 105:	total: 1.73s	remaining: 14.6s
# 106:	total: 1.74s	remaining: 14.5s
# 107:	total: 1.82s	remaining: 15s
# 108:	total: 1.82s	remaining: 14.9s
# 109:	total: 1.82s	remaining: 14.8s
# 110:	total: 1.83s	remaining: 14.6s
# 111:	total: 1.83s	remaining: 14.5s
# 112:	total: 1.84s	remaining: 14.4s
# 113:	total: 1.92s	remaining: 14.9s
# 114:	total: 1.92s	remaining: 14.8s
# 115:	total: 1.92s	remaining: 14.6s
# 116:	total: 1.92s	remaining: 14.5s
# 117:	total: 1.93s	remaining: 14.4s
# 118:	total: 1.93s	remaining: 14.3s
# 119:	total: 2.01s	remaining: 14.8s
# 120:	total: 2.02s	remaining: 14.6s
# 121:	total: 2.02s	remaining: 14.5s
# 122:	total: 2.02s	remaining: 14.4s
# 123:	total: 2.03s	remaining: 14.3s
# 124:	total: 2.11s	remaining: 14.8s
# 125:	total: 2.11s	remaining: 14.7s
# 126:	total: 2.11s	remaining: 14.5s
# 127:	total: 2.12s	remaining: 14.4s
# 128:	total: 2.12s	remaining: 14.3s
# 129:	total: 2.12s	remaining: 14.2s
# 130:	total: 2.13s	remaining: 14.2s
# 131:	total: 2.14s	remaining: 14.1s
# 132:	total: 2.14s	remaining: 13.9s
# 133:	total: 2.14s	remaining: 13.8s
# 134:	total: 2.14s	remaining: 13.7s
# 135:	total: 2.15s	remaining: 13.6s
# 136:	total: 2.15s	remaining: 13.6s
# 137:	total: 2.23s	remaining: 13.9s
# 138:	total: 2.23s	remaining: 13.8s
# 139:	total: 2.24s	remaining: 13.7s
# 140:	total: 2.24s	remaining: 13.6s
# 141:	total: 2.24s	remaining: 13.6s
# 142:	total: 2.25s	remaining: 13.5s
# 143:	total: 2.26s	remaining: 13.5s
# 144:	total: 2.33s	remaining: 13.7s
# 145:	total: 2.33s	remaining: 13.7s
# 146:	total: 2.34s	remaining: 13.6s
# 147:	total: 2.34s	remaining: 13.5s
# 148:	total: 2.35s	remaining: 13.4s
# 149:	total: 2.43s	remaining: 13.8s
# 150:	total: 2.43s	remaining: 13.7s
# 151:	total: 2.44s	remaining: 13.6s
# 152:	total: 2.44s	remaining: 13.5s
# 153:	total: 2.45s	remaining: 13.5s
# 154:	total: 2.52s	remaining: 13.8s
# 155:	total: 2.53s	remaining: 13.7s
# 156:	total: 2.53s	remaining: 13.6s
# 157:	total: 2.53s	remaining: 13.5s
# 158:	total: 2.54s	remaining: 13.4s
# 159:	total: 2.62s	remaining: 13.8s
# 160:	total: 2.62s	remaining: 13.7s
# 161:	total: 2.63s	remaining: 13.6s
# 162:	total: 2.63s	remaining: 13.5s
# 163:	total: 2.72s	remaining: 13.8s
# 164:	total: 2.72s	remaining: 13.8s
# 165:	total: 2.72s	remaining: 13.7s
# 166:	total: 2.73s	remaining: 13.6s
# 167:	total: 2.73s	remaining: 13.5s
# 168:	total: 2.73s	remaining: 13.4s
# 169:	total: 2.74s	remaining: 13.4s
# 170:	total: 2.81s	remaining: 13.6s
# 171:	total: 2.82s	remaining: 13.6s
# 172:	total: 2.82s	remaining: 13.5s
# 173:	total: 2.82s	remaining: 13.4s
# 174:	total: 2.83s	remaining: 13.4s
# 175:	total: 2.91s	remaining: 13.6s
# 176:	total: 2.91s	remaining: 13.5s
# 177:	total: 2.91s	remaining: 13.5s
# 178:	total: 2.92s	remaining: 13.4s
# 179:	total: 2.93s	remaining: 13.3s
# 180:	total: 3.01s	remaining: 13.6s
# 181:	total: 3.01s	remaining: 13.5s
# 182:	total: 3.01s	remaining: 13.4s
# 183:	total: 3.01s	remaining: 13.4s
# 184:	total: 3.02s	remaining: 13.3s
# 185:	total: 3.1s	remaining: 13.6s
# 186:	total: 3.1s	remaining: 13.5s
# 187:	total: 3.11s	remaining: 13.4s
# 188:	total: 3.11s	remaining: 13.4s
# 189:	total: 3.12s	remaining: 13.3s
# 190:	total: 3.2s	remaining: 13.5s
# 191:	total: 3.2s	remaining: 13.5s
# 192:	total: 3.21s	remaining: 13.4s
# 193:	total: 3.22s	remaining: 13.4s
# 194:	total: 3.29s	remaining: 13.6s
# 195:	total: 3.3s	remaining: 13.5s
# 196:	total: 3.3s	remaining: 13.5s
# 197:	total: 3.3s	remaining: 13.4s
# 198:	total: 3.31s	remaining: 13.3s
# 199:	total: 3.31s	remaining: 13.3s
# 200:	total: 3.39s	remaining: 13.5s
# 201:	total: 3.39s	remaining: 13.4s
# 202:	total: 3.4s	remaining: 13.3s
# 203:	total: 3.4s	remaining: 13.3s
# 204:	total: 3.4s	remaining: 13.2s
# 205:	total: 3.41s	remaining: 13.2s
# 206:	total: 3.49s	remaining: 13.4s
# 207:	total: 3.49s	remaining: 13.3s
# 208:	total: 3.5s	remaining: 13.2s
# 209:	total: 3.5s	remaining: 13.2s
# 210:	total: 3.5s	remaining: 13.1s
# 211:	total: 3.58s	remaining: 13.3s
# 212:	total: 3.59s	remaining: 13.3s
# 213:	total: 3.59s	remaining: 13.2s
# 214:	total: 3.59s	remaining: 13.1s
# 215:	total: 3.6s	remaining: 13.1s
# 216:	total: 3.68s	remaining: 13.3s
# 217:	total: 3.69s	remaining: 13.2s
# 218:	total: 3.69s	remaining: 13.2s
# 219:	total: 3.69s	remaining: 13.1s
# 220:	total: 3.69s	remaining: 13s
# 221:	total: 3.78s	remaining: 13.2s
# 222:	total: 3.78s	remaining: 13.2s
# 223:	total: 3.79s	remaining: 13.1s
# 224:	total: 3.79s	remaining: 13s
# 225:	total: 3.79s	remaining: 13s
# 226:	total: 3.8s	remaining: 12.9s
# 227:	total: 3.88s	remaining: 13.1s
# 228:	total: 3.88s	remaining: 13.1s
# 229:	total: 3.88s	remaining: 13s
# 230:	total: 3.88s	remaining: 12.9s
# 231:	total: 3.89s	remaining: 12.9s
# 232:	total: 3.9s	remaining: 12.8s
# 233:	total: 3.97s	remaining: 13s
# 234:	total: 3.98s	remaining: 12.9s
# 235:	total: 3.98s	remaining: 12.9s
# 236:	total: 3.99s	remaining: 12.8s
# 237:	total: 3.99s	remaining: 12.8s
# 238:	total: 4.07s	remaining: 13s
# 239:	total: 4.07s	remaining: 12.9s
# 240:	total: 4.08s	remaining: 12.8s
# 241:	total: 4.08s	remaining: 12.8s
# 242:	total: 4.17s	remaining: 13s
# 243:	total: 4.17s	remaining: 12.9s
# 244:	total: 4.17s	remaining: 12.9s
# 245:	total: 4.18s	remaining: 12.8s
# 246:	total: 4.18s	remaining: 12.7s
# 247:	total: 4.18s	remaining: 12.7s
# 248:	total: 4.26s	remaining: 12.9s
# 249:	total: 4.27s	remaining: 12.8s
# 250:	total: 4.27s	remaining: 12.7s
# 251:	total: 4.27s	remaining: 12.7s
# 252:	total: 4.28s	remaining: 12.6s
# 253:	total: 4.29s	remaining: 12.6s
# 254:	total: 4.36s	remaining: 12.7s
# 255:	total: 4.37s	remaining: 12.7s
# 256:	total: 4.37s	remaining: 12.6s
# 257:	total: 4.37s	remaining: 12.6s
# 258:	total: 4.37s	remaining: 12.5s
# 259:	total: 4.38s	remaining: 12.5s
# 260:	total: 4.46s	remaining: 12.6s
# 261:	total: 4.46s	remaining: 12.6s
# 262:	total: 4.46s	remaining: 12.5s
# 263:	total: 4.47s	remaining: 12.5s
# 264:	total: 4.47s	remaining: 12.4s
# 265:	total: 4.47s	remaining: 12.3s
# 266:	total: 4.56s	remaining: 12.5s
# 267:	total: 4.56s	remaining: 12.5s
# 268:	total: 4.56s	remaining: 12.4s
# 269:	total: 4.56s	remaining: 12.3s
# 270:	total: 4.57s	remaining: 12.3s
# 271:	total: 4.58s	remaining: 12.3s
# 272:	total: 4.65s	remaining: 12.4s
# 273:	total: 4.66s	remaining: 12.3s
# 274:	total: 4.66s	remaining: 12.3s
# 275:	total: 4.66s	remaining: 12.2s
# 276:	total: 4.67s	remaining: 12.2s
# 277:	total: 4.75s	remaining: 12.3s
# 278:	total: 4.75s	remaining: 12.3s
# 279:	total: 4.75s	remaining: 12.2s
# 280:	total: 4.76s	remaining: 12.2s
# 281:	total: 4.76s	remaining: 12.1s
# 282:	total: 4.77s	remaining: 12.1s
# 283:	total: 4.85s	remaining: 12.2s
# 284:	total: 4.85s	remaining: 12.2s
# 285:	total: 4.85s	remaining: 12.1s
# 286:	total: 4.86s	remaining: 12.1s
# 287:	total: 4.86s	remaining: 12s
# 288:	total: 4.94s	remaining: 12.2s
# 289:	total: 4.95s	remaining: 12.1s
# 290:	total: 4.95s	remaining: 12.1s
# 291:	total: 4.95s	remaining: 12s
# 292:	total: 4.96s	remaining: 12s
# 293:	total: 4.96s	remaining: 11.9s
# 294:	total: 5.04s	remaining: 12.1s
# 295:	total: 5.04s	remaining: 12s
# 296:	total: 5.05s	remaining: 12s
# 297:	total: 5.05s	remaining: 11.9s
# 298:	total: 5.06s	remaining: 11.9s
# 299:	total: 5.14s	remaining: 12s
# 300:	total: 5.14s	remaining: 11.9s
# 301:	total: 5.14s	remaining: 11.9s
# 302:	total: 5.15s	remaining: 11.8s
# 303:	total: 5.15s	remaining: 11.8s
# 304:	total: 5.16s	remaining: 11.8s
# 305:	total: 5.24s	remaining: 11.9s
# 306:	total: 5.24s	remaining: 11.8s
# 307:	total: 5.24s	remaining: 11.8s
# 308:	total: 5.25s	remaining: 11.7s
# 309:	total: 5.25s	remaining: 11.7s
# 310:	total: 5.26s	remaining: 11.6s
# 311:	total: 5.33s	remaining: 11.8s
# 312:	total: 5.34s	remaining: 11.7s
# 313:	total: 5.34s	remaining: 11.7s
# 314:	total: 5.34s	remaining: 11.6s
# 315:	total: 5.34s	remaining: 11.6s
# 316:	total: 5.35s	remaining: 11.5s
# 317:	total: 5.43s	remaining: 11.6s
# 318:	total: 5.43s	remaining: 11.6s
# 319:	total: 5.44s	remaining: 11.6s
# 320:	total: 5.44s	remaining: 11.5s
# 321:	total: 5.45s	remaining: 11.5s
# 322:	total: 5.45s	remaining: 11.4s
# 323:	total: 5.53s	remaining: 11.5s
# 324:	total: 5.53s	remaining: 11.5s
# 325:	total: 5.53s	remaining: 11.4s
# 326:	total: 5.54s	remaining: 11.4s
# 327:	total: 5.54s	remaining: 11.3s
# 328:	total: 5.55s	remaining: 11.3s
# 329:	total: 5.63s	remaining: 11.4s
# 330:	total: 5.63s	remaining: 11.4s
# 331:	total: 5.63s	remaining: 11.3s
# 332:	total: 5.63s	remaining: 11.3s
# 333:	total: 5.64s	remaining: 11.2s
# 334:	total: 5.64s	remaining: 11.2s
# 335:	total: 5.72s	remaining: 11.3s
# 336:	total: 5.72s	remaining: 11.3s
# 337:	total: 5.73s	remaining: 11.2s
# 338:	total: 5.73s	remaining: 11.2s
# 339:	total: 5.73s	remaining: 11.1s
# 340:	total: 5.74s	remaining: 11.1s
# 341:	total: 5.82s	remaining: 11.2s
# 342:	total: 5.82s	remaining: 11.2s
# 343:	total: 5.83s	remaining: 11.1s
# 344:	total: 5.83s	remaining: 11.1s
# 345:	total: 5.83s	remaining: 11s
# 346:	total: 5.84s	remaining: 11s
# 347:	total: 5.92s	remaining: 11.1s
# 348:	total: 5.92s	remaining: 11.1s
# 349:	total: 5.93s	remaining: 11s
# 350:	total: 5.93s	remaining: 11s
# 351:	total: 6.01s	remaining: 11.1s
# 352:	total: 6.02s	remaining: 11s
# 353:	total: 6.02s	remaining: 11s
# 354:	total: 6.02s	remaining: 10.9s
# 355:	total: 6.03s	remaining: 10.9s
# 356:	total: 6.03s	remaining: 10.9s
# 357:	total: 6.11s	remaining: 11s
# 358:	total: 6.12s	remaining: 10.9s
# 359:	total: 6.12s	remaining: 10.9s
# 360:	total: 6.12s	remaining: 10.8s
# 361:	total: 6.13s	remaining: 10.8s
# 362:	total: 6.21s	remaining: 10.9s
# 363:	total: 6.21s	remaining: 10.9s
# 364:	total: 6.21s	remaining: 10.8s
# 365:	total: 6.22s	remaining: 10.8s
# 366:	total: 6.22s	remaining: 10.7s
# 367:	total: 6.23s	remaining: 10.7s
# 368:	total: 6.31s	remaining: 10.8s
# 369:	total: 6.31s	remaining: 10.7s
# 370:	total: 6.31s	remaining: 10.7s
# 371:	total: 6.32s	remaining: 10.7s
# 372:	total: 6.32s	remaining: 10.6s
# 373:	total: 6.33s	remaining: 10.6s
# 374:	total: 6.4s	remaining: 10.7s
# 375:	total: 6.41s	remaining: 10.6s
# 376:	total: 6.41s	remaining: 10.6s
# 377:	total: 6.42s	remaining: 10.6s
# 378:	total: 6.5s	remaining: 10.7s
# 379:	total: 6.5s	remaining: 10.6s
# 380:	total: 6.51s	remaining: 10.6s
# 381:	total: 6.51s	remaining: 10.5s
# 382:	total: 6.51s	remaining: 10.5s
# 383:	total: 6.6s	remaining: 10.6s
# 384:	total: 6.6s	remaining: 10.5s
# 385:	total: 6.61s	remaining: 10.5s
# 386:	total: 6.61s	remaining: 10.5s
# ...
# 540:	total: 12s	remaining: 10.2s
# 541:	total: 12s	remaining: 10.2s
# 542:	total: 12s	remaining: 10.1s
# 543:	total: 12s	remaining: 10.1s
# 544:	total: 12.1s	remaining: 10.1s
# 545:	total: 12.1s	remaining: 10.1s
# 546:	total: 12.1s	remaining: 10s
# 547:	total: 12.1s	remaining: 10s
# 548:	total: 12.1s	remaining: 9.96s
# 549:	total: 12.2s	remaining: 9.99s
# 550:	total: 12.2s	remaining: 9.95s
# 551:	total: 12.2s	remaining: 9.91s
# 552:	total: 12.2s	remaining: 9.87s
# 553:	total: 12.2s	remaining: 9.84s
# 554:	total: 12.3s	remaining: 9.86s
# 555:	total: 12.3s	remaining: 9.83s
# 556:	total: 12.3s	remaining: 9.79s
# 557:	total: 12.3s	remaining: 9.75s
# 558:	total: 12.3s	remaining: 9.72s
# 559:	total: 12.3s	remaining: 9.69s
# 560:	total: 12.4s	remaining: 9.7s
# 561:	total: 12.4s	remaining: 9.66s
# 562:	total: 12.4s	remaining: 9.63s
# 563:	total: 12.4s	remaining: 9.59s
# 564:	total: 12.4s	remaining: 9.56s
# 565:	total: 12.5s	remaining: 9.58s
# 566:	total: 12.5s	remaining: 9.55s
# 567:	total: 12.5s	remaining: 9.51s
# 568:	total: 12.5s	remaining: 9.48s
# 569:	total: 12.6s	remaining: 9.5s
# 570:	total: 12.6s	remaining: 9.46s
# 571:	total: 12.6s	remaining: 9.43s
# 572:	total: 12.6s	remaining: 9.39s
# 573:	total: 12.6s	remaining: 9.35s
# 574:	total: 12.6s	remaining: 9.32s
# 575:	total: 12.7s	remaining: 9.34s
# 576:	total: 12.7s	remaining: 9.3s
# 577:	total: 12.7s	remaining: 9.27s
# 578:	total: 12.7s	remaining: 9.23s
# 579:	total: 12.8s	remaining: 9.26s
# 580:	total: 12.8s	remaining: 9.22s
# 581:	total: 12.8s	remaining: 9.19s
# 582:	total: 12.8s	remaining: 9.15s
# 583:	total: 12.8s	remaining: 9.12s
# 584:	total: 12.8s	remaining: 9.08s
# 585:	total: 12.9s	remaining: 9.1s
# 586:	total: 12.9s	remaining: 9.06s
# 587:	total: 12.9s	remaining: 9.03s
# 588:	total: 12.9s	remaining: 8.99s
# 589:	total: 12.9s	remaining: 8.96s
# 590:	total: 13s	remaining: 8.98s
# 591:	total: 13s	remaining: 8.95s
# 592:	total: 13s	remaining: 8.91s
# 593:	total: 13s	remaining: 8.88s
# 594:	total: 13s	remaining: 8.84s
# 595:	total: 13s	remaining: 8.82s
# 596:	total: 13.1s	remaining: 8.83s
# 597:	total: 13.1s	remaining: 8.79s
# 598:	total: 13.1s	remaining: 8.76s
# 599:	total: 13.1s	remaining: 8.73s
# 600:	total: 13.2s	remaining: 8.74s
# 601:	total: 13.2s	remaining: 8.71s
# 602:	total: 13.2s	remaining: 8.68s
# 603:	total: 13.2s	remaining: 8.64s
# 604:	total: 13.2s	remaining: 8.61s
# 605:	total: 13.2s	remaining: 8.58s
# 606:	total: 13.3s	remaining: 8.59s
# 607:	total: 13.3s	remaining: 8.56s
# 608:	total: 13.3s	remaining: 8.53s
# 609:	total: 13.3s	remaining: 8.49s
# 610:	total: 13.4s	remaining: 8.51s
# 611:	total: 13.4s	remaining: 8.48s
# 612:	total: 13.4s	remaining: 8.44s
# 613:	total: 13.4s	remaining: 8.41s
# 614:	total: 13.5s	remaining: 8.43s
# 615:	total: 13.5s	remaining: 8.4s
# 616:	total: 13.5s	remaining: 8.37s
# 617:	total: 13.5s	remaining: 8.34s
# 618:	total: 13.6s	remaining: 8.35s
# 619:	total: 13.6s	remaining: 8.32s
# 620:	total: 13.6s	remaining: 8.29s
# 621:	total: 13.6s	remaining: 8.25s
# 622:	total: 13.7s	remaining: 8.27s
# 623:	total: 13.7s	remaining: 8.23s
# 624:	total: 13.7s	remaining: 8.2s
# 625:	total: 13.7s	remaining: 8.17s
# 626:	total: 13.8s	remaining: 8.18s
# 627:	total: 13.8s	remaining: 8.15s
# 628:	total: 13.8s	remaining: 8.12s
# 629:	total: 13.8s	remaining: 8.09s
# 630:	total: 13.9s	remaining: 8.1s
# 631:	total: 13.9s	remaining: 8.07s
# 632:	total: 13.9s	remaining: 8.04s
# 633:	total: 13.9s	remaining: 8.01s
# 634:	total: 14s	remaining: 8.02s
# 635:	total: 14s	remaining: 7.99s
# 636:	total: 14s	remaining: 7.96s
# 637:	total: 14s	remaining: 7.93s
# 638:	total: 14s	remaining: 7.94s
# 639:	total: 14.1s	remaining: 7.91s
# 640:	total: 14.1s	remaining: 7.88s
# 641:	total: 14.1s	remaining: 7.85s
# 642:	total: 14.1s	remaining: 7.85s
# 643:	total: 14.2s	remaining: 7.83s
# 644:	total: 14.2s	remaining: 7.79s
# 645:	total: 14.2s	remaining: 7.76s
# 646:	total: 14.2s	remaining: 7.77s
# 647:	total: 14.3s	remaining: 7.74s
# 648:	total: 14.3s	remaining: 7.71s
# 649:	total: 14.3s	remaining: 7.68s
# 650:	total: 14.3s	remaining: 7.69s
# 651:	total: 14.4s	remaining: 7.66s
# 652:	total: 14.4s	remaining: 7.63s
# 653:	total: 14.4s	remaining: 7.64s
# 654:	total: 14.4s	remaining: 7.61s
# 655:	total: 14.5s	remaining: 7.58s
# 656:	total: 14.5s	remaining: 7.55s
# 657:	total: 14.5s	remaining: 7.55s
# 658:	total: 14.5s	remaining: 7.53s
# 659:	total: 14.5s	remaining: 7.49s
# 660:	total: 14.6s	remaining: 7.47s
# 661:	total: 14.6s	remaining: 7.47s
# 662:	total: 14.6s	remaining: 7.44s
# 663:	total: 14.6s	remaining: 7.41s
# 664:	total: 14.7s	remaining: 7.38s
# 665:	total: 14.7s	remaining: 7.39s
# 666:	total: 14.7s	remaining: 7.36s
# 667:	total: 14.7s	remaining: 7.33s
# 668:	total: 14.8s	remaining: 7.3s
# 669:	total: 14.8s	remaining: 7.3s
# 670:	total: 14.8s	remaining: 7.27s
# 671:	total: 14.8s	remaining: 7.25s
# 672:	total: 14.9s	remaining: 7.22s
# 673:	total: 14.9s	remaining: 7.22s
# 674:	total: 14.9s	remaining: 7.19s
# 675:	total: 14.9s	remaining: 7.16s
# 676:	total: 15s	remaining: 7.13s
# 677:	total: 15s	remaining: 7.14s
# 678:	total: 15s	remaining: 7.11s
# 679:	total: 15s	remaining: 7.08s
# 680:	total: 15.1s	remaining: 7.08s
# 681:	total: 15.1s	remaining: 7.05s
# 682:	total: 15.1s	remaining: 7.03s
# 683:	total: 15.1s	remaining: 7s
# 684:	total: 15.2s	remaining: 7s
# 685:	total: 15.2s	remaining: 6.97s
# 686:	total: 15.2s	remaining: 6.94s
# 687:	total: 15.2s	remaining: 6.91s
# 688:	total: 15.3s	remaining: 6.92s
# 689:	total: 15.3s	remaining: 6.88s
# 690:	total: 15.3s	remaining: 6.86s
# 691:	total: 15.3s	remaining: 6.83s
# 692:	total: 15.4s	remaining: 6.83s
# 693:	total: 15.4s	remaining: 6.8s
# 694:	total: 15.4s	remaining: 6.77s
# 695:	total: 15.4s	remaining: 6.74s
# 696:	total: 15.4s	remaining: 6.71s
# 697:	total: 15.5s	remaining: 6.71s
# 698:	total: 15.5s	remaining: 6.68s
# 699:	total: 15.5s	remaining: 6.65s
# 700:	total: 15.5s	remaining: 6.62s
# 701:	total: 15.5s	remaining: 6.59s
# 702:	total: 15.6s	remaining: 6.59s
# 703:	total: 15.6s	remaining: 6.57s
# 704:	total: 15.6s	remaining: 6.54s
# 705:	total: 15.6s	remaining: 6.51s
# 706:	total: 15.7s	remaining: 6.51s
# 707:	total: 15.7s	remaining: 6.48s
# 708:	total: 15.7s	remaining: 6.45s
# 709:	total: 15.7s	remaining: 6.42s
# 710:	total: 15.7s	remaining: 6.39s
# 711:	total: 15.7s	remaining: 6.36s
# 712:	total: 15.8s	remaining: 6.36s
# 713:	total: 15.8s	remaining: 6.33s
# 714:	total: 15.8s	remaining: 6.3s
# 715:	total: 15.8s	remaining: 6.27s
# 716:	total: 15.9s	remaining: 6.27s
# 717:	total: 15.9s	remaining: 6.25s
# 718:	total: 15.9s	remaining: 6.21s
# 719:	total: 15.9s	remaining: 6.19s
# 720:	total: 15.9s	remaining: 6.16s
# 721:	total: 15.9s	remaining: 6.13s
# 722:	total: 16s	remaining: 6.13s
# 723:	total: 16s	remaining: 6.1s
# 724:	total: 16s	remaining: 6.07s
# 725:	total: 16s	remaining: 6.04s
# 726:	total: 16.1s	remaining: 6.04s
# 727:	total: 16.1s	remaining: 6.01s
# 728:	total: 16.1s	remaining: 5.99s
# 729:	total: 16.1s	remaining: 5.96s
# 730:	total: 16.1s	remaining: 5.93s
# 731:	total: 16.2s	remaining: 5.93s
# 732:	total: 16.2s	remaining: 5.9s
# 733:	total: 16.2s	remaining: 5.87s
# 734:	total: 16.2s	remaining: 5.84s
# 735:	total: 16.2s	remaining: 5.81s
# 736:	total: 16.3s	remaining: 5.81s
# 737:	total: 16.3s	remaining: 5.78s
# 738:	total: 16.3s	remaining: 5.75s
# 739:	total: 16.3s	remaining: 5.72s
# 740:	total: 16.3s	remaining: 5.7s
# 741:	total: 16.3s	remaining: 5.67s
# 742:	total: 16.4s	remaining: 5.67s
# 743:	total: 16.4s	remaining: 5.64s
# 744:	total: 16.4s	remaining: 5.61s
# 745:	total: 16.4s	remaining: 5.58s
# 746:	total: 16.4s	remaining: 5.55s
# 747:	total: 16.5s	remaining: 5.55s
# 748:	total: 16.5s	remaining: 5.52s
# 749:	total: 16.5s	remaining: 5.5s
# 750:	total: 16.5s	remaining: 5.47s
# 751:	total: 16.5s	remaining: 5.44s
# 752:	total: 16.6s	remaining: 5.44s
# 753:	total: 16.6s	remaining: 5.41s
# 754:	total: 16.6s	remaining: 5.38s
# 755:	total: 16.6s	remaining: 5.35s
# 756:	total: 16.6s	remaining: 5.33s
# 757:	total: 16.6s	remaining: 5.3s
# 758:	total: 16.7s	remaining: 5.29s
# 759:	total: 16.7s	remaining: 5.26s
# 760:	total: 16.7s	remaining: 5.24s
# 761:	total: 16.7s	remaining: 5.21s
# 762:	total: 16.7s	remaining: 5.18s
# 763:	total: 16.7s	remaining: 5.16s
# 764:	total: 16.8s	remaining: 5.15s
# 765:	total: 16.8s	remaining: 5.12s
# 766:	total: 16.8s	remaining: 5.09s
# 767:	total: 16.8s	remaining: 5.07s
# 768:	total: 16.9s	remaining: 5.06s
# 769:	total: 16.9s	remaining: 5.04s
# 770:	total: 16.9s	remaining: 5.01s
# 771:	total: 16.9s	remaining: 4.98s
# 772:	total: 17s	remaining: 4.98s
# 773:	total: 17s	remaining: 4.95s
# 774:	total: 17s	remaining: 4.93s
# 775:	total: 17s	remaining: 4.9s
# 776:	total: 17.1s	remaining: 4.89s
# 777:	total: 17.1s	remaining: 4.87s
# 778:	total: 17.1s	remaining: 4.84s
# 779:	total: 17.1s	remaining: 4.82s
# 780:	total: 17.1s	remaining: 4.81s
# 781:	total: 17.2s	remaining: 4.78s
# 782:	total: 17.2s	remaining: 4.76s
# 783:	total: 17.2s	remaining: 4.73s
# 784:	total: 17.2s	remaining: 4.72s
# 785:	total: 17.3s	remaining: 4.7s
# 786:	total: 17.3s	remaining: 4.67s
# 787:	total: 17.3s	remaining: 4.65s
# 788:	total: 17.3s	remaining: 4.64s
# 789:	total: 17.4s	remaining: 4.61s
# 790:	total: 17.4s	remaining: 4.59s
# 791:	total: 17.4s	remaining: 4.56s
# 792:	total: 17.4s	remaining: 4.55s
# 793:	total: 17.4s	remaining: 4.53s
# 794:	total: 17.5s	remaining: 4.5s
# 795:	total: 17.5s	remaining: 4.47s
# 796:	total: 17.5s	remaining: 4.47s
# 797:	total: 17.5s	remaining: 4.44s
# 798:	total: 17.6s	remaining: 4.42s
# 799:	total: 17.6s	remaining: 4.39s
# 800:	total: 17.6s	remaining: 4.36s
# 801:	total: 17.6s	remaining: 4.35s
# 802:	total: 17.6s	remaining: 4.33s
# 803:	total: 17.6s	remaining: 4.3s
# 804:	total: 17.7s	remaining: 4.28s
# 805:	total: 17.7s	remaining: 4.27s
# 806:	total: 17.7s	remaining: 4.24s
# 807:	total: 17.8s	remaining: 4.22s
# 808:	total: 17.8s	remaining: 4.21s
# 809:	total: 17.8s	remaining: 4.18s
# 810:	total: 17.8s	remaining: 4.16s
# 811:	total: 17.9s	remaining: 4.13s
# 812:	total: 17.9s	remaining: 4.12s
# 813:	total: 17.9s	remaining: 4.1s
# 814:	total: 17.9s	remaining: 4.07s
# 815:	total: 18s	remaining: 4.05s
# 816:	total: 18s	remaining: 4.04s
# 817:	total: 18s	remaining: 4.01s
# 818:	total: 18s	remaining: 3.99s
# 819:	total: 18s	remaining: 3.96s
# 820:	total: 18s	remaining: 3.93s
# 821:	total: 18.1s	remaining: 3.92s
# 822:	total: 18.1s	remaining: 3.9s
# 823:	total: 18.1s	remaining: 3.87s
# 824:	total: 18.1s	remaining: 3.85s
# 825:	total: 18.2s	remaining: 3.84s
# 826:	total: 18.2s	remaining: 3.81s
# 827:	total: 18.2s	remaining: 3.79s
# 828:	total: 18.3s	remaining: 3.78s
# 829:	total: 18.3s	remaining: 3.75s
# 830:	total: 18.3s	remaining: 3.73s
# 831:	total: 18.3s	remaining: 3.7s
# 832:	total: 18.4s	remaining: 3.69s
# 833:	total: 18.4s	remaining: 3.67s
# 834:	total: 18.4s	remaining: 3.64s
# 835:	total: 18.4s	remaining: 3.62s
# 836:	total: 18.4s	remaining: 3.59s
# 837:	total: 18.5s	remaining: 3.58s
# 838:	total: 18.5s	remaining: 3.55s
# 839:	total: 18.5s	remaining: 3.53s
# 840:	total: 18.5s	remaining: 3.5s
# 841:	total: 18.6s	remaining: 3.49s
# 842:	total: 18.6s	remaining: 3.47s
# 843:	total: 18.6s	remaining: 3.44s
# 844:	total: 18.6s	remaining: 3.42s
# 845:	total: 18.7s	remaining: 3.4s
# 846:	total: 18.7s	remaining: 3.38s
# 847:	total: 18.7s	remaining: 3.36s
# 848:	total: 18.8s	remaining: 3.34s
# 849:	total: 18.8s	remaining: 3.32s
# 850:	total: 18.8s	remaining: 3.29s
# 851:	total: 18.8s	remaining: 3.27s
# 852:	total: 18.8s	remaining: 3.25s
# 853:	total: 18.9s	remaining: 3.23s
# 854:	total: 18.9s	remaining: 3.21s
# 855:	total: 18.9s	remaining: 3.18s
# 856:	total: 19s	remaining: 3.17s
# 857:	total: 19s	remaining: 3.15s
# 858:	total: 19s	remaining: 3.12s
# 859:	total: 19s	remaining: 3.1s
# 860:	total: 19s	remaining: 3.07s
# 861:	total: 19s	remaining: 3.05s
# 862:	total: 19s	remaining: 3.02s
# 863:	total: 19.1s	remaining: 3s
# 864:	total: 19.1s	remaining: 2.98s
# 865:	total: 19.1s	remaining: 2.96s
# 866:	total: 19.1s	remaining: 2.94s
# 867:	total: 19.2s	remaining: 2.91s
# 868:	total: 19.2s	remaining: 2.89s
# 869:	total: 19.2s	remaining: 2.87s
# 870:	total: 19.2s	remaining: 2.85s
# 871:	total: 19.2s	remaining: 2.82s
# 872:	total: 19.2s	remaining: 2.8s
# 873:	total: 19.3s	remaining: 2.79s
# 874:	total: 19.3s	remaining: 2.76s
# 875:	total: 19.3s	remaining: 2.74s
# 876:	total: 19.4s	remaining: 2.71s
# 877:	total: 19.4s	remaining: 2.7s
# 878:	total: 19.4s	remaining: 2.67s
# 879:	total: 19.4s	remaining: 2.65s
# 880:	total: 19.4s	remaining: 2.63s
# 881:	total: 19.5s	remaining: 2.61s
# 882:	total: 19.5s	remaining: 2.59s
# 883:	total: 19.5s	remaining: 2.56s
# 884:	total: 19.6s	remaining: 2.54s
# 885:	total: 19.6s	remaining: 2.52s
# 886:	total: 19.6s	remaining: 2.5s
# 887:	total: 19.6s	remaining: 2.48s
# 888:	total: 19.6s	remaining: 2.45s
# 889:	total: 19.7s	remaining: 2.44s
# 890:	total: 19.7s	remaining: 2.41s
# 891:	total: 19.7s	remaining: 2.39s
# 892:	total: 19.7s	remaining: 2.36s
# 893:	total: 19.7s	remaining: 2.34s
# 894:	total: 19.8s	remaining: 2.32s
# 895:	total: 19.8s	remaining: 2.3s
# 896:	total: 19.8s	remaining: 2.28s
# 897:	total: 19.8s	remaining: 2.25s
# 898:	total: 19.9s	remaining: 2.24s
# 899:	total: 19.9s	remaining: 2.21s
# 900:	total: 19.9s	remaining: 2.19s
# 901:	total: 19.9s	remaining: 2.17s
# 902:	total: 20s	remaining: 2.15s
# 903:	total: 20s	remaining: 2.13s
# 904:	total: 20s	remaining: 2.1s
# 905:	total: 20s	remaining: 2.08s
# 906:	total: 20.1s	remaining: 2.06s
# 907:	total: 20.1s	remaining: 2.04s
# 908:	total: 20.1s	remaining: 2.01s
# 909:	total: 20.1s	remaining: 1.99s
# 910:	total: 20.2s	remaining: 1.97s
# 911:	total: 20.2s	remaining: 1.95s
# 912:	total: 20.2s	remaining: 1.93s
# 913:	total: 20.2s	remaining: 1.9s
# 914:	total: 20.3s	remaining: 1.89s
# 915:	total: 20.3s	remaining: 1.86s
# 916:	total: 20.3s	remaining: 1.84s
# 917:	total: 20.3s	remaining: 1.81s
# 918:	total: 20.4s	remaining: 1.8s
# 919:	total: 20.4s	remaining: 1.77s
# 920:	total: 20.4s	remaining: 1.75s
# 921:	total: 20.4s	remaining: 1.73s
# 922:	total: 20.4s	remaining: 1.7s
# 923:	total: 20.4s	remaining: 1.68s
# 924:	total: 20.5s	remaining: 1.66s
# 925:	total: 20.5s	remaining: 1.64s
# 926:	total: 20.5s	remaining: 1.61s
# 927:	total: 20.5s	remaining: 1.59s
# 928:	total: 20.5s	remaining: 1.57s
# 929:	total: 20.6s	remaining: 1.55s
# 930:	total: 20.6s	remaining: 1.53s
# 931:	total: 20.6s	remaining: 1.5s
# 932:	total: 20.6s	remaining: 1.48s
# 933:	total: 20.6s	remaining: 1.46s
# 934:	total: 20.6s	remaining: 1.43s
# 935:	total: 20.7s	remaining: 1.41s
# 936:	total: 20.7s	remaining: 1.39s
# 937:	total: 20.7s	remaining: 1.37s
# 938:	total: 20.7s	remaining: 1.34s
# 939:	total: 20.7s	remaining: 1.32s
# 940:	total: 20.8s	remaining: 1.3s
# 941:	total: 20.8s	remaining: 1.28s
# 942:	total: 20.8s	remaining: 1.26s
# 943:	total: 20.8s	remaining: 1.23s
# 944:	total: 20.8s	remaining: 1.21s
# 945:	total: 20.9s	remaining: 1.19s
# 946:	total: 20.9s	remaining: 1.17s
# 947:	total: 20.9s	remaining: 1.15s
# 948:	total: 20.9s	remaining: 1.12s
# 949:	total: 21s	remaining: 1.1s
# 950:	total: 21s	remaining: 1.08s
# 951:	total: 21s	remaining: 1.06s
# 952:	total: 21s	remaining: 1.03s
# 953:	total: 21s	remaining: 1.01s
# 954:	total: 21.1s	remaining: 993ms
# 955:	total: 21.1s	remaining: 971ms
# 956:	total: 21.1s	remaining: 948ms
# 957:	total: 21.2s	remaining: 928ms
# 958:	total: 21.2s	remaining: 906ms
# 959:	total: 21.2s	remaining: 883ms
# 960:	total: 21.2s	remaining: 860ms
# 961:	total: 21.2s	remaining: 837ms
# 962:	total: 21.3s	remaining: 817ms
# 963:	total: 21.3s	remaining: 795ms
# 964:	total: 21.3s	remaining: 772ms
# 965:	total: 21.3s	remaining: 749ms
# 966:	total: 21.3s	remaining: 726ms
# 967:	total: 21.3s	remaining: 704ms
# 968:	total: 21.4s	remaining: 684ms
# 969:	total: 21.4s	remaining: 661ms
# 970:	total: 21.4s	remaining: 638ms
# 971:	total: 21.4s	remaining: 616ms
# 972:	total: 21.4s	remaining: 593ms
# 973:	total: 21.5s	remaining: 573ms
# 974:	total: 21.5s	remaining: 551ms
# 975:	total: 21.5s	remaining: 528ms
# 976:	total: 21.5s	remaining: 506ms
# 977:	total: 21.5s	remaining: 483ms
# 978:	total: 21.5s	remaining: 461ms
# 979:	total: 21.6s	remaining: 440ms
# 980:	total: 21.6s	remaining: 418ms
# 981:	total: 21.6s	remaining: 395ms
# 982:	total: 21.6s	remaining: 373ms
# 983:	total: 21.6s	remaining: 351ms
# 984:	total: 21.7s	remaining: 330ms
# 985:	total: 21.7s	remaining: 308ms
# 986:	total: 21.7s	remaining: 285ms
# 987:	total: 21.7s	remaining: 263ms
# 988:	total: 21.7s	remaining: 241ms
# 989:	total: 21.8s	remaining: 220ms
# 990:	total: 21.8s	remaining: 198ms
# 991:	total: 21.8s	remaining: 176ms
# 992:	total: 21.8s	remaining: 153ms
# 993:	total: 21.8s	remaining: 131ms
# 994:	total: 21.9s	remaining: 110ms
# 995:	total: 21.9s	remaining: 87.8ms
# 996:	total: 21.9s	remaining: 65.8ms
# 997:	total: 21.9s	remaining: 43.8ms
# 998:	total: 21.9s	remaining: 21.9ms
# 999:	total: 22s	remaining: 0us
# valid_Roc_auc score:  0.9254782525935092

# %%
# Results from Grid Search
print("\n========================================================")
print(" Results from Grid Search " )
print("========================================================")    
    
print("\n The best estimator across ALL searched params:\n",
          grid.best_estimator_)
print("\n The best score across ALL searched params:\n",
          grid.best_score_)
print("\n The best parameters across ALL searched params:\n",
          grid.best_params_)
print("\n ========================================================")
# Out:
# ========================================================
#  Results from Grid Search
# ========================================================
#
#  The best estimator across ALL searched params:
#  <catboost.core.CatBoostClassifier object at 0x7f3f0d22acd0>
#
#  The best score across ALL searched params:
#  0.8665314401622718
#
#  The best parameters across ALL searched params:
#  {'depth': 4, 'l2_leaf_reg': 1, 'learning_rate': 0.1}
#
#  ========================================================

# %%
#используем найденные гиперпараметры для обучения и проверки на тестовой выборке
model_cb = CatBoostClassifier(depth = 4, learning_rate = 0.1, l2_leaf_reg = 1, eval_metric='AUC', random_state=12345)
model_cb.fit(X_train, y_train, verbose=100, plot=False)

probabilities_valid = model_cb.predict_proba(X_test)
probabilities_one_valid = probabilities_valid[:, 1]

fpr_cb, tpr_cb, threshold_cb = metrics.roc_curve(y_test, probabilities_one_valid)
roc_auc = metrics.auc(fpr_cb, tpr_cb)    

print('test_Roc_auc score: ',roc_auc)

pred_cb=model_cb.predict(X_test)
print(classification_report(y_test, pred_cb))
# Out:
# 0:	total: 3.36ms	remaining: 3.36s
# 100:	total: 2.06s	remaining: 18.3s
# 200:	total: 4.4s	remaining: 17.5s
# 300:	total: 6.58s	remaining: 15.3s
# 400:	total: 9.04s	remaining: 13.5s
# 500:	total: 11.2s	remaining: 11.1s
# 600:	total: 13.4s	remaining: 8.92s
# 700:	total: 15.8s	remaining: 6.72s
# 800:	total: 18s	remaining: 4.48s
# 900:	total: 19.9s	remaining: 2.19s
# 999:	total: 22.3s	remaining: 0us
# test_Roc_auc score:  0.9113713001124015
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92       785
#            1       0.78      0.73      0.75       272
#
#     accuracy                           0.88      1057
#    macro avg       0.85      0.83      0.84      1057
# weighted avg       0.88      0.88      0.88      1057

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера</b>
#
# Шаг выполнен просто отлично. Тюнинг дал отличный прирост метрики, молодец!
#
# </div>

# %% [markdown]
# # Лучшие модели

# %%
#run models


#calculate values for ROC AUC plot

plt.figure(figsize=(12,8))
plt.plot(fpr_rfc, tpr_rfc, label='RandomForestClassifier (area = %0.4f)' % metrics.auc(fpr_rfc, tpr_rfc))
plt.plot(fpr_gbl, tpr_gbl, label='GGradientBoostingClassifier (area = %0.4f)' % metrics.auc(fpr_gbl, tpr_gbl))
plt.plot(fpr_lgb, tpr_lgb, label='LGBMClassifier (area = %0.4f)' % metrics.auc(fpr_lgb, tpr_lgb))
plt.plot(fpr_cb, tpr_cb, label='CatBoostClassifier (area = %0.4f)' % metrics.auc(fpr_cb, tpr_cb))

plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Сравнение моделей на тестовой выборке')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %%
print('Метрики для тестовой выборки после тюнинга', '\n')
print('RandomForestClassifier (ROC AUC= %0.4f)' % metrics.auc(fpr_rfc, tpr_rfc),
      '(accuracy= %0.4f)' % accuracy_score(y_test, pred_rfc),'\n')
print('GradientBoostingClassifier (ROC AUC= %0.4f)' % metrics.auc(fpr_gbl, tpr_gbl),
      '(accuracy= %0.4f)' % accuracy_score(y_test, pred_gbl),'\n')
print('LGBMClassifier (ROC AUC= %0.4f)' % metrics.auc(fpr_lgb, tpr_lgb),
      '(accuracy= %0.4f)' % accuracy_score(y_test, pred_lgb),'\n')
print('CatBoost (ROC AUC= %0.4f)' % metrics.auc(fpr_cb, tpr_cb),
      '(accuracy= %0.4f)' % accuracy_score(y_test, pred_cb),'\n')
# Out:
# Метрики для тестовой выборки после тюнинга
#
# RandomForestClassifier (ROC AUC= 0.8503) (accuracy= 0.8240)
#
# GradientBoostingClassifier (ROC AUC= 0.9147) (accuracy= 0.8657)
#
# LGBMClassifier (ROC AUC= 0.8925) (accuracy= 0.8534)
#
# CatBoost (ROC AUC= 0.9114) (accuracy= 0.8780)

# %% [markdown]
# <div class="alert alert-info"> <b>Дополнил:</b> Объеденим train и valid и обучим лучшую модель на общей выборке. предскажем на тестовой, построим матрицу ошибок</div>

# %%
# Объеденим train и valid и обучим лучшую модель на общей выборке. предскажем на тестовой
X_train_s=pd.concat([X_train, X_valid])
y_train_s=pd.concat([y_train, y_valid])

model_gbl_s = GradientBoostingClassifier(learning_rate=0.03, n_estimators=1750,max_depth=4,  
                                     subsample=1, random_state=12)
model_gbl_s.fit(X_train_s, y_train_s)

probabilities_valid_s = model_gbl_s.predict_proba(X_test)
probabilities_one_valid_s = probabilities_valid_s[:, 1]

fpr_gbl_s, tpr_gbl_s, threshold_gbl_s = metrics.roc_curve(y_test, probabilities_one_valid_s)
roc_auc_s = metrics.auc(fpr_gbl_s, tpr_gbl_s)    

pred_gbl_s=model_gbl_s.predict(X_test)

# %%
def plot_confusion_matrix(y_test , y_pred , classes = None , figsize = (10 , 10) , text_size = 10):
  import tensorflow as tf
  import itertools  
  # Setting the default figsize 
  figsize = figsize
  # Create the confusion matrix from sklearn 
  cm = confusion_matrix(y_test , tf.math.round(y_pred))
  cm_norm = cm.astype('float') / cm.sum(axis = 1)[: , np.newaxis] # Normalize our confusion matrix 

  # Number of clases
  n_classes = cm.shape[0]

  # Making our plot pretty
  fig , ax = plt.subplots(figsize = figsize)
  # Drawing the matrix plot 
  cax = ax.matshow(cm , cmap = plt.cm.Blues)
  fig.colorbar(cax)

  # Set labels to be classes
  if classes:
    labels = classes
  else:
    labels = np.arange(cm.shape[0])

  # Label axes
  ax.set(title ='Confusion Matrix' , 
       xlabel = 'Predicted Label' , 
       ylabel = 'True Label' , 
       xticks = np.arange(n_classes) , 
       yticks = np.arange(n_classes) , 
       xticklabels = labels , 
       yticklabels = labels)
  # Set the xaxis labels to bottom 
  ax.xaxis.set_label_position('bottom')
  ax.xaxis.tick_bottom()

  # Adjust the label size 
  ax.yaxis.label.set_size(text_size)
  ax.xaxis.label.set_size(text_size)
  ax.title.set_size(text_size)

  # Set threshold for different colors 
  threshold = (cm.max() + cm.min()) / 2

  # Plot the text on each cell 
  for i , j in itertools.product(range(cm.shape[0]) , range(cm.shape[1])):
    plt.text(j , i , f'{cm[i , j]} ({cm_norm[i , j]*100:.1f}%)' , 
           horizontalalignment = 'center' , 
            color = 'white' if cm[i , j] > threshold else 'black' , 
           size = text_size)
    
plot_confusion_matrix(y_test, pred_cb)
print()
print('===================================  лучший результат  =================================================','\n')
print(classification_report(y_test, pred_gbl_s))

print('GradientBoosting (ROC AUC= %0.4f)' % metrics.auc(fpr_gbl_s, tpr_gbl_s),
      '(accuracy= %0.4f)' % accuracy_score(y_test, pred_gbl_s),'\n')
# Out:
# ===================================лучший результат=================================================
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92       785
#            1       0.78      0.73      0.75       272
#
#     accuracy                           0.88      1057
#    macro avg       0.84      0.83      0.83      1057
# weighted avg       0.87      0.88      0.87      1057
#
# GradientBoosting (ROC AUC= 0.9206) (accuracy= 0.8761)

# %% [markdown]
# Лучший результат на тестовой выборке = 0,9206, получился на модели GradientBoosting с тюнингом, при обучении на объединенных train и valid выборок

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера (v2)</b>
#
# Результат просто отличный.
#
# </div>

# %% [markdown]
# # Вывод:
#
# Лучший результат на тестовой выборке показали CatBoost и GradientBoosting около 0.91
# Разбивка 70% train, 15% valid, 15% test.
# Введены дополнительные фичи, которые помогли добиться более точного прогноза
# Oversampling с помощью SMOTE не дал улучшения предсказания.
# С помощью тюнинга удалось улудшить предсказание
#
# из графика важности фичей для модели на основе RandomForester с помощью пакета shap
# можно увидеть внутреннюю 'кухню' модели предсказаний и оценить важность признаков
#
# Портрет уходящего клиента из графика важности фичей:
#
# недавно заключивший контракт, подключенный к интернету по оптической линии,
# с высокой помесячной оплатой,получающий электронный чек,
# тип оплаты electronic check и не автоматический, пользующийся стриминговыми сервисами.
#
# Модель достаточно хорошо предсказывает поведение клиента. Можно рекомендовать заказчику обратить внимание на клиентов с учетом предсказания и анализа важности признаков, по портрету, указанному выше

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера</b>
#
# Хороший, цельный и подробный проект. Спасибо за основательный подход к делу.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий ревьюера</b>
#
# Еще всегда полезно посмотреть на матрицу ошибок и дать ее интерпретацию - это важные показатели для бизнеса.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера (v2)</b>
#
# Теперь все круто.
#
# </div>

# %% [markdown]
# # Отчет по решению
#
# Вопросы:
#
# * Какие пункты плана были выполнены, а какие — нет (поясните почему)?
#
#
# 1. Чтение файлов с данными и изучение общей информаций -  ВЫПОЛНЕН
# 2. Создание дополнительных признаков (target_churn, phone, internet,срок контракта в месяцах, предлагаются дополнительные признаки: разделить клиентов на короткие и длинные договора, низкий или высокий ежемесячный платеж) ВЫПОЛНЕН и дополнен
#     Введены дополнительные фичи для улучшения качества метрики:
# 'days_contract' количество дней контракта,
# pay_auto_contract'  платеж с признаком авто,
# 'type_year_contract'  ежемесячный или годовой платеж
# Отказался от признака internet, как не влияющего на метрику
# 3. Слияние в единый датафрейм  ВЫПОЛНЕН
# 4. Исключение признаков с датами и TotalCharges.  ВЫПОЛНЕН с изменением
# TotalCharges - оставлен, удаление ухудшает качество
# 5. Кодирование категориальных признаков и нормализация численных. Разделение на train и valid ВЫПОЛНЕН
# 6. Обучение модели RandomForest, Выбор важных признаков, удаление ненужных признаков  ВЫПОЛНЕН с изменениями
# признаки не удалялись в результатет анализа, удаление признаков не улудшило метрику
# 7. Обучение нескольких моделей (от простых к сложным) на сформированной выборке. выбор перспективных. Тюнинг модели  ВЫПОЛНЕН
# 8. Выводы и рекомендации ВЫПОЛНЕН
#
#
# * Какие трудности возникли и как вы их преодолели?
#
# Долго не удавалось добиться нужного качества. Для улучшения качества был найдены фичи , которые, как показал последующий анализ графика важности фичей для модели на основе RandomForester с помощью пакета SHAP, являются одними из самых важных признаков для данной задачи.
# 'days_contract' количество дней контракта - 1 место по важности
# 'type_year_contract'  ежемесячный или годовой платеж - 3 место по важности,
# что в конечном итоге  позволило добиться высоких показателей метрики без дополнительного тюнинга (ROC AUC от 0.82 до 0,90 на валидационной выборпке в зависимости от модели)
#
# * Какие ключевые шаги в решении задачи выделили?
#
# Ключевые шаги для решения были обработка даных, их изучение, создание дополнительных фич в результате анализа. Оценка данных для получения максимального качества модели. Анализ 11 моделей (от простых к сложным ). Анализ важности фичей с помощь пакета SHAP. Учлучшение качества 4 моделей с помощью тюнинга (GradientBoosting с 0.88 до 0.92 на valid)
#
#
# * Какая ваша итоговая модель и какое у неё качество?
#
#
# Лучший результат на тестовой выборке ROC AUC= 0,9206, получился на модели GradientBoosting с тюнингом, при обучении на объединенных train и valid выборках при следующих параметрах
#  {'learning_rate': 0.03, 'max_depth': 4, 'n_estimators': 1750, 'subsample': 1}

# %% [markdown]
# ================лучший результат  GradientBoosting=================================================
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92       785
#            1       0.78      0.73      0.75       272
#
#     accuracy                           0.88      1057
#    macro avg       0.84      0.83      0.83      1057
# weighted avg       0.87      0.88      0.87      1057
#
# GradientBoosting (ROC AUC= 0.9206) (accuracy= 0.8761) ,
#
#             Confusion Matrix
#
#                        Predicted label
#                |       0       |        1        |
# true label | 0 |  730 (93.0%)  |    55 ( 7.0%)   |
#            | 1 |   74 (27.2%)  |   178 (72.8%)   |
